# %%
import os
import re
import requests
from urllib.parse import urljoin

# ------------------------------------------------------------
# 1) Proxy setup (isolated, reusable)
# ------------------------------------------------------------
def setup_dwd_proxy(proxy="http://ofsquid.dwd.de:8080"):
    os.environ["HTTP_PROXY"]  = proxy
    os.environ["HTTPS_PROXY"] = proxy
    os.environ["http_proxy"]  = proxy
    os.environ["https_proxy"] = proxy
    return {"http": proxy, "https": proxy}

proxies = setup_dwd_proxy()

# %%
# ============================================================
# DWD OpenData NWP – per-leaf sampling crawler (fast + complete)
# - visits all directories up to MAX_DEPTH
# - if a directory contains files: sample only N files, do NOT go deeper
# - optionally skips runtime dirs like 2025123100/
# - shows live progress (overwrites line)
# ============================================================

SAMPLE_FILES_PER_LEAF = 3
SKIP_RUNTIME_DIRS = True

def show_progress(msg: str):
    print(f"\r{msg:140}", end="", flush=True)

def is_runtime_dir(name: str) -> bool:
    n = name.rstrip("/")
    return n.isdigit() and len(n) in (8, 10, 12)

def crawl_sampled(url: str, max_depth=MAX_DEPTH):
    """
    Crawl directories (depth-first) and collect *sampled* files from every leaf directory
    (leaf := directory containing any files).

    Returns:
      dirs: list of visited directories
      files: list of sampled file URLs (up to SAMPLE_FILES_PER_LEAF per leaf dir)
    """
    seen_dirs = set()
    dirs = []
    files = []

    def _rec(u, depth):
        show_progress(f"Crawling: {u}")

        if depth > max_depth:
            return
        if not u.endswith("/"):
            u += "/"
        if u in seen_dirs:
            return

        seen_dirs.add(u)
        dirs.append(u)

        try:
            links = fetch_links(u)
        except Exception:
            return

        # Split into dirs/files
        local_files = [l for l in links if not is_dir(l)]
        local_dirs  = [l for l in links if is_dir(l)]

        # If files exist here, sample and STOP descending below this directory
        if local_files:
            for f in local_files[:SAMPLE_FILES_PER_LEAF]:
                files.append(urljoin(u, f))
            return

        # Otherwise recurse into subdirectories
        for d in local_dirs:
            if SKIP_RUNTIME_DIRS and is_runtime_dir(d):
                continue
            _rec(urljoin(u, d), depth + 1)

    _rec(url, 0)
    print("\rCrawling complete." + " " * 100)
    return dirs, files


def summarize_model(model: str):
    model_url = urljoin(BASE_ROOT, f"{model}/")
    dirs, files = crawl_sampled(model_url, max_depth=MAX_DEPTH)

    product_map = {}

    def parent_dir(file_url: str) -> str:
        return file_url.rsplit("/", 1)[0] + "/"

    for fu in files:
        fname = fu.rsplit("/", 1)[-1]
        fmt = file_format(fname)
        if fmt not in ("grib", "netcdf"):
            continue

        pdir = parent_dir(fu)

        if pdir not in product_map:
            product_map[pdir] = {
                "product_dir": pdir,
                "formats": set(),
                "sample_files": {"grib": [], "netcdf": []},
                "variables": set(),
                "templates": set(),
            }

        entry = product_map[pdir]
        entry["formats"].add(fmt)

        # keep up to SAMPLE_FILES_PER_LEAF per format per product dir
        if len(entry["sample_files"][fmt]) < SAMPLE_FILES_PER_LEAF:
            entry["sample_files"][fmt].append(fu)
            entry["templates"].add(make_template(fname))
            var = extract_variable_from_filename(fname)
            if var:
                entry["variables"].add(var)

    products = []
    for pdir, v in sorted(product_map.items()):
        products.append({
            "product_dir": pdir,
            "formats": sorted(v["formats"]),
            "variables": sorted(v["variables"]),
            "templates": sorted(v["templates"]),
            "sample_files": v["sample_files"],
        })

    return {
        "model": model,
        "base_url": model_url,
        "crawl": {
            "max_depth": MAX_DEPTH,
            "dirs_visited": len(dirs),
            "leaf_dirs_with_samples": len(product_map),
            "files_sampled_total": len(files),
            "sample_files_per_leaf": SAMPLE_FILES_PER_LEAF,
            "skip_runtime_dirs": SKIP_RUNTIME_DIRS,
        },
        "products": products,
        "generated_at": datetime.now(UTC).strftime("%Y-%m-%d %H:%M:%S UTC"),
    }

# %%
# ---------- run ----------
inventory = {"root": BASE_ROOT, "models": {}}
for m in MODELS:
    print(f"\n=== Scanning {m} ===")
    inventory["models"][m] = summarize_model(m)

# ---------- save machine-readable JSON ----------
json_path = "dwd_nwp_inventory.json"
with open(json_path, "w", encoding="utf-8") as f:
    json.dump(inventory, f, indent=2, ensure_ascii=False)

print(f"\n✅ Saved machine-readable inventory: {json_path}")
# Out:
# === Scanning icon ===
# Crawling complete.
#
# === Scanning icon-eu ===
# Crawling complete.
#
# === Scanning icon-d2 ===
# Crawling complete.
#
# ✅ Saved machine-readable inventory: dwd_nwp_inventory.json
#
# --- Human-readable summary (Markdown) ---
#
# | model   | product_dir                          | formats   |   #vars | vars (sample)                              | template (sample)                                                                               |
# |:--------|:-------------------------------------|:----------|--------:|:-------------------------------------------|:------------------------------------------------------------------------------------------------|
# | icon    | icon/grib/00/alb_rad/                | grib      |       1 | SINGLE-LEVEL_ALB_RAD                       | icon_global_icosahedral_single-level_{ref_time}_{lead}_ALB_RAD.grib2.bz2                        |
# | icon    | icon/grib/00/alb_seaice/             | grib      |       1 | TIME-INVARIANT_ALB_SEAICE                  | icon_global_icosahedral_time-invariant_{ref_time}_ALB_SEAICE.grib2.bz2                          |
# | icon    | icon/grib/00/alhfl_s/                | grib      |       1 | SINGLE-LEVEL_ALHFL_S                       | icon_global_icosahedral_single-level_{ref_time}_{lead}_ALHFL_S.grib2.bz2                        |
# | icon    | icon/grib/00/ashfl_s/                | grib      |       1 | SINGLE-LEVEL_ASHFL_S                       | icon_global_icosahedral_single-level_{ref_time}_{lead}_ASHFL_S.grib2.bz2                        |
# | icon    | icon/grib/00/asob_s/                 | grib      |       1 | SINGLE-LEVEL_ASOB_S                        | icon_global_icosahedral_single-level_{ref_time}_{lead}_ASOB_S.grib2.bz2                         |
# | icon    | icon/grib/00/asob_s_cs/              | grib      |       1 | ASOB_S_CS                                  | icon_global_icosahedral_single-level_{ref_time}_{lead}_ASOB_S_CS.grib2.bz2                      |
# | icon    | icon/grib/00/asob_t/                 | grib      |       1 | SINGLE-LEVEL_ASOB_T                        | icon_global_icosahedral_single-level_{ref_time}_{lead}_ASOB_T.grib2.bz2                         |
# | icon    | icon/grib/00/aswdifd_s/              | grib      |       1 | SINGLE-LEVEL_ASWDIFD_S                     | icon_global_icosahedral_single-level_{ref_time}_{lead}_ASWDIFD_S.grib2.bz2                      |
# | icon    | icon/grib/00/aswdifu_s/              | grib      |       1 | SINGLE-LEVEL_ASWDIFU_S                     | icon_global_icosahedral_single-level_{ref_time}_{lead}_ASWDIFU_S.grib2.bz2                      |
# | icon    | icon/grib/00/aswdir_s/               | grib      |       1 | SINGLE-LEVEL_ASWDIR_S                      | icon_global_icosahedral_single-level_{ref_time}_{lead}_ASWDIR_S.grib2.bz2                       |
# | icon    | icon/grib/00/athb_s/                 | grib      |       1 | SINGLE-LEVEL_ATHB_S                        | icon_global_icosahedral_single-level_{ref_time}_{lead}_ATHB_S.grib2.bz2                         |
# | icon    | icon/grib/00/athb_t/                 | grib      |       1 | SINGLE-LEVEL_ATHB_T                        | icon_global_icosahedral_single-level_{ref_time}_{lead}_ATHB_T.grib2.bz2                         |
# | icon    | icon/grib/00/aumfl_s/                | grib      |       1 | SINGLE-LEVEL_AUMFL_S                       | icon_global_icosahedral_single-level_{ref_time}_{lead}_AUMFL_S.grib2.bz2                        |
# | icon    | icon/grib/00/avmfl_s/                | grib      |       1 | SINGLE-LEVEL_AVMFL_S                       | icon_global_icosahedral_single-level_{ref_time}_{lead}_AVMFL_S.grib2.bz2                        |
# | icon    | icon/grib/00/c_t_lk/                 | grib      |       1 | C_T_LK                                     | icon_global_icosahedral_single-level_{ref_time}_{lead}_C_T_LK.grib2.bz2                         |
# | icon    | icon/grib/00/cape_con/               | grib      |       1 | SINGLE-LEVEL_CAPE_CON                      | icon_global_icosahedral_single-level_{ref_time}_{lead}_CAPE_CON.grib2.bz2                       |
# | icon    | icon/grib/00/cape_ml/                | grib      |       1 | SINGLE-LEVEL_CAPE_ML                       | icon_global_icosahedral_single-level_{ref_time}_{lead}_CAPE_ML.grib2.bz2                        |
# | icon    | icon/grib/00/clat/                   | grib      |       1 | ICOSAHEDRAL_TIME-INVARIANT_CLAT            | icon_global_icosahedral_time-invariant_{ref_time}_CLAT.grib2.bz2                                |
# | icon    | icon/grib/00/clc/                    | grib      |       1 | ICOSAHEDRAL_MODEL-LEVEL_CLC                | icon_global_icosahedral_model-level_{ref_time}_{lead}_{lead}_CLC.grib2.bz2                      |
# | icon    | icon/grib/00/clch/                   | grib      |       1 | ICOSAHEDRAL_SINGLE-LEVEL_CLCH              | icon_global_icosahedral_single-level_{ref_time}_{lead}_CLCH.grib2.bz2                           |
# | icon    | icon/grib/00/clcl/                   | grib      |       1 | ICOSAHEDRAL_SINGLE-LEVEL_CLCL              | icon_global_icosahedral_single-level_{ref_time}_{lead}_CLCL.grib2.bz2                           |
# | icon    | icon/grib/00/clcm/                   | grib      |       1 | ICOSAHEDRAL_SINGLE-LEVEL_CLCM              | icon_global_icosahedral_single-level_{ref_time}_{lead}_CLCM.grib2.bz2                           |
# | icon    | icon/grib/00/clct/                   | grib      |       1 | ICOSAHEDRAL_SINGLE-LEVEL_CLCT              | icon_global_icosahedral_single-level_{ref_time}_{lead}_CLCT.grib2.bz2                           |
# | icon    | icon/grib/00/clct_mod/               | grib      |       1 | SINGLE-LEVEL_CLCT_MOD                      | icon_global_icosahedral_single-level_{ref_time}_{lead}_CLCT_MOD.grib2.bz2                       |
# | icon    | icon/grib/00/cldepth/                | grib      |       1 | ICOSAHEDRAL_SINGLE-LEVEL_CLDEPTH           | icon_global_icosahedral_single-level_{ref_time}_{lead}_CLDEPTH.grib2.bz2                        |
# | icon    | icon/grib/00/clon/                   | grib      |       1 | ICOSAHEDRAL_TIME-INVARIANT_CLON            | icon_global_icosahedral_time-invariant_{ref_time}_CLON.grib2.bz2                                |
# | icon    | icon/grib/00/depth_lk/               | grib      |       1 | TIME-INVARIANT_DEPTH_LK                    | icon_global_icosahedral_time-invariant_{ref_time}_DEPTH_LK.grib2.bz2                            |
# | icon    | icon/grib/00/elat/                   | grib      |       1 | ICOSAHEDRAL_TIME-INVARIANT_ELAT            | icon_global_icosahedral_time-invariant_{ref_time}_ELAT.grib2.bz2                                |
# | icon    | icon/grib/00/elon/                   | grib      |       1 | ICOSAHEDRAL_TIME-INVARIANT_ELON            | icon_global_icosahedral_time-invariant_{ref_time}_ELON.grib2.bz2                                |
# | icon    | icon/grib/00/evap_pl/                | grib      |       1 | TIME-INVARIANT_EVAP_PL                     | icon_global_icosahedral_time-invariant_{ref_time}_EVAP_PL.grib2.bz2                             |
# | icon    | icon/grib/00/fi/                     | grib      |       1 | ICOSAHEDRAL_PRESSURE-LEVEL_FI              | icon_global_icosahedral_pressure-level_{ref_time}_{lead}_{lead}_FI.grib2.bz2                    |
# | icon    | icon/grib/00/fr_ice/                 | grib      |       1 | SINGLE-LEVEL_FR_ICE                        | icon_global_icosahedral_single-level_{ref_time}_{lead}_FR_ICE.grib2.bz2                         |
# | icon    | icon/grib/00/fr_lake/                | grib      |       1 | TIME-INVARIANT_FR_LAKE                     | icon_global_icosahedral_time-invariant_{ref_time}_FR_LAKE.grib2.bz2                             |
# | icon    | icon/grib/00/fr_land/                | grib      |       1 | TIME-INVARIANT_FR_LAND                     | icon_global_icosahedral_time-invariant_{ref_time}_FR_LAND.grib2.bz2                             |
# | icon    | icon/grib/00/freshsnw/               | grib      |       1 | ICOSAHEDRAL_SINGLE-LEVEL_FRESHSNW          | icon_global_icosahedral_single-level_{ref_time}_{lead}_FRESHSNW.grib2.bz2                       |
# | icon    | icon/grib/00/h_ice/                  | grib      |       1 | SINGLE-LEVEL_H_ICE                         | icon_global_icosahedral_single-level_{ref_time}_{lead}_H_ICE.grib2.bz2                          |
# | icon    | icon/grib/00/h_ml_lk/                | grib      |       1 | H_ML_LK                                    | icon_global_icosahedral_single-level_{ref_time}_{lead}_H_ML_LK.grib2.bz2                        |
# | icon    | icon/grib/00/h_snow/                 | grib      |       1 | SINGLE-LEVEL_H_SNOW                        | icon_global_icosahedral_single-level_{ref_time}_{lead}_H_SNOW.grib2.bz2                         |
# | icon    | icon/grib/00/hbas_con/               | grib      |       1 | SINGLE-LEVEL_HBAS_CON                      | icon_global_icosahedral_single-level_{ref_time}_{lead}_HBAS_CON.grib2.bz2                       |
# | icon    | icon/grib/00/hhl/                    | grib      |       1 | ICOSAHEDRAL_TIME-INVARIANT_HHL             | icon_global_icosahedral_time-invariant_{ref_time}_{lead}_HHL.grib2.bz2                          |
# | icon    | icon/grib/00/hsnow_max/              | grib      |       1 | TIME-INVARIANT_HSNOW_MAX                   | icon_global_icosahedral_time-invariant_{ref_time}_HSNOW_MAX.grib2.bz2                           |
# | icon    | icon/grib/00/hsurf/                  | grib      |       1 | ICOSAHEDRAL_TIME-INVARIANT_HSURF           | icon_global_icosahedral_time-invariant_{ref_time}_HSURF.grib2.bz2                               |
# | icon    | icon/grib/00/htop_con/               | grib      |       1 | SINGLE-LEVEL_HTOP_CON                      | icon_global_icosahedral_single-level_{ref_time}_{lead}_HTOP_CON.grib2.bz2                       |
# | icon    | icon/grib/00/htop_dc/                | grib      |       1 | SINGLE-LEVEL_HTOP_DC                       | icon_global_icosahedral_single-level_{ref_time}_{lead}_HTOP_DC.grib2.bz2                        |
# | icon    | icon/grib/00/hzerocl/                | grib      |       1 | ICOSAHEDRAL_SINGLE-LEVEL_HZEROCL           | icon_global_icosahedral_single-level_{ref_time}_{lead}_HZEROCL.grib2.bz2                        |
# | icon    | icon/grib/00/lai/                    | grib      |       1 | ICOSAHEDRAL_TIME-INVARIANT_LAI             | icon_global_icosahedral_time-invariant_{ref_time}_LAI.grib2.bz2                                 |
# | icon    | icon/grib/00/ndviratio/              | grib      |       1 | ICOSAHEDRAL_TIME-INVARIANT_NDVIRATIO       | icon_global_icosahedral_time-invariant_{ref_time}_NDVIRATIO.grib2.bz2                           |
# | icon    | icon/grib/00/p/                      | grib      |       1 | ICOSAHEDRAL_MODEL-LEVEL_P                  | icon_global_icosahedral_model-level_{ref_time}_{lead}_{lead}_P.grib2.bz2                        |
# | icon    | icon/grib/00/plcov/                  | grib      |       1 | ICOSAHEDRAL_TIME-INVARIANT_PLCOV           | icon_global_icosahedral_time-invariant_{ref_time}_PLCOV.grib2.bz2                               |
# | icon    | icon/grib/00/pmsl/                   | grib      |       1 | ICOSAHEDRAL_SINGLE-LEVEL_PMSL              | icon_global_icosahedral_single-level_{ref_time}_{lead}_PMSL.grib2.bz2                           |
# | icon    | icon/grib/00/ps/                     | grib      |       1 | ICOSAHEDRAL_SINGLE-LEVEL_PS                | icon_global_icosahedral_single-level_{ref_time}_{lead}_PS.grib2.bz2                             |
# | icon    | icon/grib/00/qc/                     | grib      |       1 | ICOSAHEDRAL_MODEL-LEVEL_QC                 | icon_global_icosahedral_model-level_{ref_time}_{lead}_{lead}_QC.grib2.bz2                       |
# | icon    | icon/grib/00/qi/                     | grib      |       1 | ICOSAHEDRAL_MODEL-LEVEL_QI                 | icon_global_icosahedral_model-level_{ref_time}_{lead}_{lead}_QI.grib2.bz2                       |
# | icon    | icon/grib/00/qv/                     | grib      |       1 | ICOSAHEDRAL_MODEL-LEVEL_QV                 | icon_global_icosahedral_model-level_{ref_time}_{lead}_{lead}_QV.grib2.bz2                       |
# | icon    | icon/grib/00/qv_s/                   | grib      |       1 | SINGLE-LEVEL_QV_S                          | icon_global_icosahedral_single-level_{ref_time}_{lead}_QV_S.grib2.bz2                           |
# | icon    | icon/grib/00/rain_con/               | grib      |       1 | SINGLE-LEVEL_RAIN_CON                      | icon_global_icosahedral_single-level_{ref_time}_{lead}_RAIN_CON.grib2.bz2                       |
# | icon    | icon/grib/00/rain_gsp/               | grib      |       1 | SINGLE-LEVEL_RAIN_GSP                      | icon_global_icosahedral_single-level_{ref_time}_{lead}_RAIN_GSP.grib2.bz2                       |
# | icon    | icon/grib/00/relhum/                 | grib      |       1 | ICOSAHEDRAL_PRESSURE-LEVEL_RELHUM          | icon_global_icosahedral_pressure-level_{ref_time}_{lead}_{lead}_RELHUM.grib2.bz2                |
# | icon    | icon/grib/00/relhum_2m/              | grib      |       1 | SINGLE-LEVEL_RELHUM_2M                     | icon_global_icosahedral_single-level_{ref_time}_{lead}_RELHUM_2M.grib2.bz2                      |
# | icon    | icon/grib/00/rho_snow/               | grib      |       1 | SINGLE-LEVEL_RHO_SNOW                      | icon_global_icosahedral_single-level_{ref_time}_{lead}_RHO_SNOW.grib2.bz2                       |
# | icon    | icon/grib/00/rootdp/                 | grib      |       1 | ICOSAHEDRAL_TIME-INVARIANT_ROOTDP          | icon_global_icosahedral_time-invariant_{ref_time}_ROOTDP.grib2.bz2                              |
# | icon    | icon/grib/00/runoff_g/               | grib      |       1 | SINGLE-LEVEL_RUNOFF_G                      | icon_global_icosahedral_single-level_{ref_time}_{lead}_RUNOFF_G.grib2.bz2                       |
# | icon    | icon/grib/00/runoff_s/               | grib      |       1 | SINGLE-LEVEL_RUNOFF_S                      | icon_global_icosahedral_single-level_{ref_time}_{lead}_RUNOFF_S.grib2.bz2                       |
# | icon    | icon/grib/00/snoag/                  | grib      |       1 | ICOSAHEDRAL_TIME-INVARIANT_SNOAG           | icon_global_icosahedral_time-invariant_{ref_time}_SNOAG.grib2.bz2                               |
# | icon    | icon/grib/00/snow_con/               | grib      |       1 | SINGLE-LEVEL_SNOW_CON                      | icon_global_icosahedral_single-level_{ref_time}_{lead}_SNOW_CON.grib2.bz2                       |
# | icon    | icon/grib/00/snow_gsp/               | grib      |       1 | SINGLE-LEVEL_SNOW_GSP                      | icon_global_icosahedral_single-level_{ref_time}_{lead}_SNOW_GSP.grib2.bz2                       |
# | icon    | icon/grib/00/soiltyp/                | grib      |       1 | ICOSAHEDRAL_TIME-INVARIANT_SOILTYP         | icon_global_icosahedral_time-invariant_{ref_time}_SOILTYP.grib2.bz2                             |
# | icon    | icon/grib/00/t/                      | grib      |       1 | ICOSAHEDRAL_MODEL-LEVEL_T                  | icon_global_icosahedral_model-level_{ref_time}_{lead}_{lead}_T.grib2.bz2                        |
# | icon    | icon/grib/00/t_2m/                   | grib      |       1 | SINGLE-LEVEL_T_2M                          | icon_global_icosahedral_single-level_{ref_time}_{lead}_T_2M.grib2.bz2                           |
# | icon    | icon/grib/00/t_bot_lk/               | grib      |       1 | T_BOT_LK                                   | icon_global_icosahedral_single-level_{ref_time}_{lead}_T_BOT_LK.grib2.bz2                       |
# | icon    | icon/grib/00/t_g/                    | grib      |       1 | SINGLE-LEVEL_T_G                           | icon_global_icosahedral_single-level_{ref_time}_{lead}_T_G.grib2.bz2                            |
# | icon    | icon/grib/00/t_ice/                  | grib      |       1 | SINGLE-LEVEL_T_ICE                         | icon_global_icosahedral_single-level_{ref_time}_{lead}_T_ICE.grib2.bz2                          |
# | icon    | icon/grib/00/t_mnw_lk/               | grib      |       1 | T_MNW_LK                                   | icon_global_icosahedral_single-level_{ref_time}_{lead}_T_MNW_LK.grib2.bz2                       |
# | icon    | icon/grib/00/t_snow/                 | grib      |       1 | SINGLE-LEVEL_T_SNOW                        | icon_global_icosahedral_single-level_{ref_time}_{lead}_T_SNOW.grib2.bz2                         |
# | icon    | icon/grib/00/t_so/                   | grib      |       2 | SOIL-LEVEL_T_SO, T_SO                      | icon_global_icosahedral_soil-level_{ref_time}_{lead}_0_T_SO.grib2.bz2                           |
# | icon    | icon/grib/00/t_wml_lk/               | grib      |       1 | T_WML_LK                                   | icon_global_icosahedral_single-level_{ref_time}_{lead}_T_WML_LK.grib2.bz2                       |
# | icon    | icon/grib/00/tch/                    | grib      |       1 | ICOSAHEDRAL_SINGLE-LEVEL_TCH               | icon_global_icosahedral_single-level_{ref_time}_{lead}_TCH.grib2.bz2                            |
# | icon    | icon/grib/00/tcm/                    | grib      |       1 | ICOSAHEDRAL_SINGLE-LEVEL_TCM               | icon_global_icosahedral_single-level_{ref_time}_{lead}_TCM.grib2.bz2                            |
# | icon    | icon/grib/00/td_2m/                  | grib      |       1 | SINGLE-LEVEL_TD_2M                         | icon_global_icosahedral_single-level_{ref_time}_{lead}_TD_2M.grib2.bz2                          |
# | icon    | icon/grib/00/tke/                    | grib      |       1 | ICOSAHEDRAL_MODEL-LEVEL_TKE                | icon_global_icosahedral_model-level_{ref_time}_{lead}_{lead}_TKE.grib2.bz2                      |
# | icon    | icon/grib/00/tmax_2m/                | grib      |       1 | SINGLE-LEVEL_TMAX_2M                       | icon_global_icosahedral_single-level_{ref_time}_{lead}_TMAX_2M.grib2.bz2                        |
# | icon    | icon/grib/00/tmin_2m/                | grib      |       1 | SINGLE-LEVEL_TMIN_2M                       | icon_global_icosahedral_single-level_{ref_time}_{lead}_TMIN_2M.grib2.bz2                        |
# | icon    | icon/grib/00/tot_prec/               | grib      |       1 | SINGLE-LEVEL_TOT_PREC                      | icon_global_icosahedral_single-level_{ref_time}_{lead}_TOT_PREC.grib2.bz2                       |
# | icon    | icon/grib/00/tqc/                    | grib      |       1 | ICOSAHEDRAL_SINGLE-LEVEL_TQC               | icon_global_icosahedral_single-level_{ref_time}_{lead}_TQC.grib2.bz2                            |
# | icon    | icon/grib/00/tqc_dia/                | grib      |       1 | SINGLE-LEVEL_TQC_DIA                       | icon_global_icosahedral_single-level_{ref_time}_{lead}_TQC_DIA.grib2.bz2                        |
# | icon    | icon/grib/00/tqi/                    | grib      |       1 | ICOSAHEDRAL_SINGLE-LEVEL_TQI               | icon_global_icosahedral_single-level_{ref_time}_{lead}_TQI.grib2.bz2                            |
# | icon    | icon/grib/00/tqi_dia/                | grib      |       1 | SINGLE-LEVEL_TQI_DIA                       | icon_global_icosahedral_single-level_{ref_time}_{lead}_TQI_DIA.grib2.bz2                        |
# | icon    | icon/grib/00/tqr/                    | grib      |       1 | ICOSAHEDRAL_SINGLE-LEVEL_TQR               | icon_global_icosahedral_single-level_{ref_time}_{lead}_TQR.grib2.bz2                            |
# | icon    | icon/grib/00/tqs/                    | grib      |       1 | ICOSAHEDRAL_SINGLE-LEVEL_TQS               | icon_global_icosahedral_single-level_{ref_time}_{lead}_TQS.grib2.bz2                            |
# | icon    | icon/grib/00/tqv/                    | grib      |       1 | ICOSAHEDRAL_SINGLE-LEVEL_TQV               | icon_global_icosahedral_single-level_{ref_time}_{lead}_TQV.grib2.bz2                            |
# | icon    | icon/grib/00/u/                      | grib      |       1 | ICOSAHEDRAL_MODEL-LEVEL_U                  | icon_global_icosahedral_model-level_{ref_time}_{lead}_{lead}_U.grib2.bz2                        |
# | icon    | icon/grib/00/u_10m/                  | grib      |       1 | SINGLE-LEVEL_U_10M                         | icon_global_icosahedral_single-level_{ref_time}_{lead}_U_{lead}M.grib2.bz2                      |
# | icon    | icon/grib/00/v/                      | grib      |       1 | ICOSAHEDRAL_MODEL-LEVEL_V                  | icon_global_icosahedral_model-level_{ref_time}_{lead}_{lead}_V.grib2.bz2                        |
# | icon    | icon/grib/00/v_10m/                  | grib      |       1 | SINGLE-LEVEL_V_10M                         | icon_global_icosahedral_single-level_{ref_time}_{lead}_V_{lead}M.grib2.bz2                      |
# | icon    | icon/grib/00/vmax_10m/               | grib      |       1 | SINGLE-LEVEL_VMAX_10M                      | icon_global_icosahedral_single-level_{ref_time}_{lead}_VMAX_{lead}M.grib2.bz2                   |
# | icon    | icon/grib/00/w/                      | grib      |       1 | ICOSAHEDRAL_MODEL-LEVEL_W                  | icon_global_icosahedral_model-level_{ref_time}_{lead}_{lead}_W.grib2.bz2                        |
# | icon    | icon/grib/00/w_i/                    | grib      |       1 | SINGLE-LEVEL_W_I                           | icon_global_icosahedral_single-level_{ref_time}_{lead}_W_I.grib2.bz2                            |
# | icon    | icon/grib/00/w_snow/                 | grib      |       1 | SINGLE-LEVEL_W_SNOW                        | icon_global_icosahedral_single-level_{ref_time}_{lead}_W_SNOW.grib2.bz2                         |
# | icon    | icon/grib/00/w_so/                   | grib      |       2 | SOIL-LEVEL_W_SO, W_SO                      | icon_global_icosahedral_soil-level_{ref_time}_{lead}_0_W_SO.grib2.bz2                           |
# | icon    | icon/grib/00/w_so_ice/               | grib      |       1 | W_SO_ICE                                   | icon_global_icosahedral_soil-level_{ref_time}_{lead}_0_W_SO_ICE.grib2.bz2                       |
# | icon    | icon/grib/00/ww/                     | grib      |       1 | ICOSAHEDRAL_SINGLE-LEVEL_WW                | icon_global_icosahedral_single-level_{ref_time}_{lead}_WW.grib2.bz2                             |
# | icon    | icon/grib/00/z0/                     | grib      |       1 | ICOSAHEDRAL_SINGLE-LEVEL_Z0                | icon_global_icosahedral_single-level_{ref_time}_{lead}_Z0.grib2.bz2                             |
# | icon    | icon/grib/06/alb_rad/                | grib      |       1 | SINGLE-LEVEL_ALB_RAD                       | icon_global_icosahedral_single-level_{ref_time}_{lead}_ALB_RAD.grib2.bz2                        |
# | icon    | icon/grib/06/alb_seaice/             | grib      |       1 | TIME-INVARIANT_ALB_SEAICE                  | icon_global_icosahedral_time-invariant_{ref_time}_ALB_SEAICE.grib2.bz2                          |
# | icon    | icon/grib/06/alhfl_s/                | grib      |       1 | SINGLE-LEVEL_ALHFL_S                       | icon_global_icosahedral_single-level_{ref_time}_{lead}_ALHFL_S.grib2.bz2                        |
# | icon    | icon/grib/06/ashfl_s/                | grib      |       1 | SINGLE-LEVEL_ASHFL_S                       | icon_global_icosahedral_single-level_{ref_time}_{lead}_ASHFL_S.grib2.bz2                        |
# | icon    | icon/grib/06/asob_s/                 | grib      |       1 | SINGLE-LEVEL_ASOB_S                        | icon_global_icosahedral_single-level_{ref_time}_{lead}_ASOB_S.grib2.bz2                         |
# | icon    | icon/grib/06/asob_s_cs/              | grib      |       1 | ASOB_S_CS                                  | icon_global_icosahedral_single-level_{ref_time}_{lead}_ASOB_S_CS.grib2.bz2                      |
# | icon    | icon/grib/06/asob_t/                 | grib      |       1 | SINGLE-LEVEL_ASOB_T                        | icon_global_icosahedral_single-level_{ref_time}_{lead}_ASOB_T.grib2.bz2                         |
# | icon    | icon/grib/06/aswdifd_s/              | grib      |       1 | SINGLE-LEVEL_ASWDIFD_S                     | icon_global_icosahedral_single-level_{ref_time}_{lead}_ASWDIFD_S.grib2.bz2                      |
# | icon    | icon/grib/06/aswdifu_s/              | grib      |       1 | SINGLE-LEVEL_ASWDIFU_S                     | icon_global_icosahedral_single-level_{ref_time}_{lead}_ASWDIFU_S.grib2.bz2                      |
# | icon    | icon/grib/06/aswdir_s/               | grib      |       1 | SINGLE-LEVEL_ASWDIR_S                      | icon_global_icosahedral_single-level_{ref_time}_{lead}_ASWDIR_S.grib2.bz2                       |
# | icon    | icon/grib/06/athb_s/                 | grib      |       1 | SINGLE-LEVEL_ATHB_S                        | icon_global_icosahedral_single-level_{ref_time}_{lead}_ATHB_S.grib2.bz2                         |
# | icon    | icon/grib/06/athb_t/                 | grib      |       1 | SINGLE-LEVEL_ATHB_T                        | icon_global_icosahedral_single-level_{ref_time}_{lead}_ATHB_T.grib2.bz2                         |
# | icon    | icon/grib/06/aumfl_s/                | grib      |       1 | SINGLE-LEVEL_AUMFL_S                       | icon_global_icosahedral_single-level_{ref_time}_{lead}_AUMFL_S.grib2.bz2                        |
# | icon    | icon/grib/06/avmfl_s/                | grib      |       1 | SINGLE-LEVEL_AVMFL_S                       | icon_global_icosahedral_single-level_{ref_time}_{lead}_AVMFL_S.grib2.bz2                        |
# | icon    | icon/grib/06/c_t_lk/                 | grib      |       1 | C_T_LK                                     | icon_global_icosahedral_single-level_{ref_time}_{lead}_C_T_LK.grib2.bz2                         |
# | icon    | icon/grib/06/cape_con/               | grib      |       1 | SINGLE-LEVEL_CAPE_CON                      | icon_global_icosahedral_single-level_{ref_time}_{lead}_CAPE_CON.grib2.bz2                       |
# | icon    | icon/grib/06/cape_ml/                | grib      |       1 | SINGLE-LEVEL_CAPE_ML                       | icon_global_icosahedral_single-level_{ref_time}_{lead}_CAPE_ML.grib2.bz2                        |
# | icon    | icon/grib/06/clat/                   | grib      |       1 | ICOSAHEDRAL_TIME-INVARIANT_CLAT            | icon_global_icosahedral_time-invariant_{ref_time}_CLAT.grib2.bz2                                |
# | icon    | icon/grib/06/clc/                    | grib      |       1 | ICOSAHEDRAL_MODEL-LEVEL_CLC                | icon_global_icosahedral_model-level_{ref_time}_{lead}_{lead}_CLC.grib2.bz2                      |
# | icon    | icon/grib/06/clch/                   | grib      |       1 | ICOSAHEDRAL_SINGLE-LEVEL_CLCH              | icon_global_icosahedral_single-level_{ref_time}_{lead}_CLCH.grib2.bz2                           |
# | icon    | icon/grib/06/clcl/                   | grib      |       1 | ICOSAHEDRAL_SINGLE-LEVEL_CLCL              | icon_global_icosahedral_single-level_{ref_time}_{lead}_CLCL.grib2.bz2                           |
# | icon    | icon/grib/06/clcm/                   | grib      |       1 | ICOSAHEDRAL_SINGLE-LEVEL_CLCM              | icon_global_icosahedral_single-level_{ref_time}_{lead}_CLCM.grib2.bz2                           |
# | icon    | icon/grib/06/clct/                   | grib      |       1 | ICOSAHEDRAL_SINGLE-LEVEL_CLCT              | icon_global_icosahedral_single-level_{ref_time}_{lead}_CLCT.grib2.bz2                           |
# | icon    | icon/grib/06/clct_mod/               | grib      |       1 | SINGLE-LEVEL_CLCT_MOD                      | icon_global_icosahedral_single-level_{ref_time}_{lead}_CLCT_MOD.grib2.bz2                       |
# | icon    | icon/grib/06/cldepth/                | grib      |       1 | ICOSAHEDRAL_SINGLE-LEVEL_CLDEPTH           | icon_global_icosahedral_single-level_{ref_time}_{lead}_CLDEPTH.grib2.bz2                        |
# | icon    | icon/grib/06/clon/                   | grib      |       1 | ICOSAHEDRAL_TIME-INVARIANT_CLON            | icon_global_icosahedral_time-invariant_{ref_time}_CLON.grib2.bz2                                |
# | icon    | icon/grib/06/depth_lk/               | grib      |       1 | TIME-INVARIANT_DEPTH_LK                    | icon_global_icosahedral_time-invariant_{ref_time}_DEPTH_LK.grib2.bz2                            |
# | icon    | icon/grib/06/elat/                   | grib      |       1 | ICOSAHEDRAL_TIME-INVARIANT_ELAT            | icon_global_icosahedral_time-invariant_{ref_time}_ELAT.grib2.bz2                                |
# | icon    | icon/grib/06/elon/                   | grib      |       1 | ICOSAHEDRAL_TIME-INVARIANT_ELON            | icon_global_icosahedral_time-invariant_{ref_time}_ELON.grib2.bz2                                |
# | icon    | icon/grib/06/evap_pl/                | grib      |       1 | TIME-INVARIANT_EVAP_PL                     | icon_global_icosahedral_time-invariant_{ref_time}_EVAP_PL.grib2.bz2                             |
# | icon    | icon/grib/06/fi/                     | grib      |       1 | ICOSAHEDRAL_PRESSURE-LEVEL_FI              | icon_global_icosahedral_pressure-level_{ref_time}_{lead}_{lead}_FI.grib2.bz2                    |
# | icon    | icon/grib/06/fr_ice/                 | grib      |       1 | SINGLE-LEVEL_FR_ICE                        | icon_global_icosahedral_single-level_{ref_time}_{lead}_FR_ICE.grib2.bz2                         |
# | icon    | icon/grib/06/fr_lake/                | grib      |       1 | TIME-INVARIANT_FR_LAKE                     | icon_global_icosahedral_time-invariant_{ref_time}_FR_LAKE.grib2.bz2                             |
# | icon    | icon/grib/06/fr_land/                | grib      |       1 | TIME-INVARIANT_FR_LAND                     | icon_global_icosahedral_time-invariant_{ref_time}_FR_LAND.grib2.bz2                             |
# | icon    | icon/grib/06/freshsnw/               | grib      |       1 | ICOSAHEDRAL_SINGLE-LEVEL_FRESHSNW          | icon_global_icosahedral_single-level_{ref_time}_{lead}_FRESHSNW.grib2.bz2                       |
# | icon    | icon/grib/06/h_ice/                  | grib      |       1 | SINGLE-LEVEL_H_ICE                         | icon_global_icosahedral_single-level_{ref_time}_{lead}_H_ICE.grib2.bz2                          |
# | icon    | icon/grib/06/h_ml_lk/                | grib      |       1 | H_ML_LK                                    | icon_global_icosahedral_single-level_{ref_time}_{lead}_H_ML_LK.grib2.bz2                        |
# | icon    | icon/grib/06/h_snow/                 | grib      |       1 | SINGLE-LEVEL_H_SNOW                        | icon_global_icosahedral_single-level_{ref_time}_{lead}_H_SNOW.grib2.bz2                         |
# | icon    | icon/grib/06/hbas_con/               | grib      |       1 | SINGLE-LEVEL_HBAS_CON                      | icon_global_icosahedral_single-level_{ref_time}_{lead}_HBAS_CON.grib2.bz2                       |
# | icon    | icon/grib/06/hhl/                    | grib      |       1 | ICOSAHEDRAL_TIME-INVARIANT_HHL             | icon_global_icosahedral_time-invariant_{ref_time}_{lead}_HHL.grib2.bz2                          |
# | icon    | icon/grib/06/hsnow_max/              | grib      |       1 | TIME-INVARIANT_HSNOW_MAX                   | icon_global_icosahedral_time-invariant_{ref_time}_HSNOW_MAX.grib2.bz2                           |
# | icon    | icon/grib/06/hsurf/                  | grib      |       1 | ICOSAHEDRAL_TIME-INVARIANT_HSURF           | icon_global_icosahedral_time-invariant_{ref_time}_HSURF.grib2.bz2                               |
# | icon    | icon/grib/06/htop_con/               | grib      |       1 | SINGLE-LEVEL_HTOP_CON                      | icon_global_icosahedral_single-level_{ref_time}_{lead}_HTOP_CON.grib2.bz2                       |
# | icon    | icon/grib/06/htop_dc/                | grib      |       1 | SINGLE-LEVEL_HTOP_DC                       | icon_global_icosahedral_single-level_{ref_time}_{lead}_HTOP_DC.grib2.bz2                        |
# | icon    | icon/grib/06/hzerocl/                | grib      |       1 | ICOSAHEDRAL_SINGLE-LEVEL_HZEROCL           | icon_global_icosahedral_single-level_{ref_time}_{lead}_HZEROCL.grib2.bz2                        |
# | icon    | icon/grib/06/lai/                    | grib      |       1 | ICOSAHEDRAL_TIME-INVARIANT_LAI             | icon_global_icosahedral_time-invariant_{ref_time}_LAI.grib2.bz2                                 |
# | icon    | icon/grib/06/ndviratio/              | grib      |       1 | ICOSAHEDRAL_TIME-INVARIANT_NDVIRATIO       | icon_global_icosahedral_time-invariant_{ref_time}_NDVIRATIO.grib2.bz2                           |
# | icon    | icon/grib/06/p/                      | grib      |       1 | ICOSAHEDRAL_MODEL-LEVEL_P                  | icon_global_icosahedral_model-level_{ref_time}_{lead}_{lead}_P.grib2.bz2                        |
# | icon    | icon/grib/06/plcov/                  | grib      |       1 | ICOSAHEDRAL_TIME-INVARIANT_PLCOV           | icon_global_icosahedral_time-invariant_{ref_time}_PLCOV.grib2.bz2                               |
# | icon    | icon/grib/06/pmsl/                   | grib      |       1 | ICOSAHEDRAL_SINGLE-LEVEL_PMSL              | icon_global_icosahedral_single-level_{ref_time}_{lead}_PMSL.grib2.bz2                           |
# | icon    | icon/grib/06/ps/                     | grib      |       1 | ICOSAHEDRAL_SINGLE-LEVEL_PS                | icon_global_icosahedral_single-level_{ref_time}_{lead}_PS.grib2.bz2                             |
# | icon    | icon/grib/06/qc/                     | grib      |       1 | ICOSAHEDRAL_MODEL-LEVEL_QC                 | icon_global_icosahedral_model-level_{ref_time}_{lead}_{lead}_QC.grib2.bz2                       |
# | icon    | icon/grib/06/qi/                     | grib      |       1 | ICOSAHEDRAL_MODEL-LEVEL_QI                 | icon_global_icosahedral_model-level_{ref_time}_{lead}_{lead}_QI.grib2.bz2                       |
# | icon    | icon/grib/06/qv/                     | grib      |       1 | ICOSAHEDRAL_MODEL-LEVEL_QV                 | icon_global_icosahedral_model-level_{ref_time}_{lead}_{lead}_QV.grib2.bz2                       |
# | icon    | icon/grib/06/qv_s/                   | grib      |       1 | SINGLE-LEVEL_QV_S                          | icon_global_icosahedral_single-level_{ref_time}_{lead}_QV_S.grib2.bz2                           |
# | icon    | icon/grib/06/rain_con/               | grib      |       1 | SINGLE-LEVEL_RAIN_CON                      | icon_global_icosahedral_single-level_{ref_time}_{lead}_RAIN_CON.grib2.bz2                       |
# | icon    | icon/grib/06/rain_gsp/               | grib      |       1 | SINGLE-LEVEL_RAIN_GSP                      | icon_global_icosahedral_single-level_{ref_time}_{lead}_RAIN_GSP.grib2.bz2                       |
# | icon    | icon/grib/06/relhum/                 | grib      |       1 | ICOSAHEDRAL_PRESSURE-LEVEL_RELHUM          | icon_global_icosahedral_pressure-level_{ref_time}_{lead}_{lead}_RELHUM.grib2.bz2                |
# | icon    | icon/grib/06/relhum_2m/              | grib      |       1 | SINGLE-LEVEL_RELHUM_2M                     | icon_global_icosahedral_single-level_{ref_time}_{lead}_RELHUM_2M.grib2.bz2                      |
# | icon    | icon/grib/06/rho_snow/               | grib      |       1 | SINGLE-LEVEL_RHO_SNOW                      | icon_global_icosahedral_single-level_{ref_time}_{lead}_RHO_SNOW.grib2.bz2                       |
# | icon    | icon/grib/06/rootdp/                 | grib      |       1 | ICOSAHEDRAL_TIME-INVARIANT_ROOTDP          | icon_global_icosahedral_time-invariant_{ref_time}_ROOTDP.grib2.bz2                              |
# | icon    | icon/grib/06/runoff_g/               | grib      |       1 | SINGLE-LEVEL_RUNOFF_G                      | icon_global_icosahedral_single-level_{ref_time}_{lead}_RUNOFF_G.grib2.bz2                       |
# | icon    | icon/grib/06/runoff_s/               | grib      |       1 | SINGLE-LEVEL_RUNOFF_S                      | icon_global_icosahedral_single-level_{ref_time}_{lead}_RUNOFF_S.grib2.bz2                       |
# | icon    | icon/grib/06/snoag/                  | grib      |       1 | ICOSAHEDRAL_TIME-INVARIANT_SNOAG           | icon_global_icosahedral_time-invariant_{ref_time}_SNOAG.grib2.bz2                               |
# | icon    | icon/grib/06/snow_con/               | grib      |       1 | SINGLE-LEVEL_SNOW_CON                      | icon_global_icosahedral_single-level_{ref_time}_{lead}_SNOW_CON.grib2.bz2                       |
# | icon    | icon/grib/06/snow_gsp/               | grib      |       1 | SINGLE-LEVEL_SNOW_GSP                      | icon_global_icosahedral_single-level_{ref_time}_{lead}_SNOW_GSP.grib2.bz2                       |
# | icon    | icon/grib/06/soiltyp/                | grib      |       1 | ICOSAHEDRAL_TIME-INVARIANT_SOILTYP         | icon_global_icosahedral_time-invariant_{ref_time}_SOILTYP.grib2.bz2                             |
# | icon    | icon/grib/06/t/                      | grib      |       1 | ICOSAHEDRAL_MODEL-LEVEL_T                  | icon_global_icosahedral_model-level_{ref_time}_{lead}_{lead}_T.grib2.bz2                        |
# | icon    | icon/grib/06/t_2m/                   | grib      |       1 | SINGLE-LEVEL_T_2M                          | icon_global_icosahedral_single-level_{ref_time}_{lead}_T_2M.grib2.bz2                           |
# | icon    | icon/grib/06/t_bot_lk/               | grib      |       1 | T_BOT_LK                                   | icon_global_icosahedral_single-level_{ref_time}_{lead}_T_BOT_LK.grib2.bz2                       |
# | icon    | icon/grib/06/t_g/                    | grib      |       1 | SINGLE-LEVEL_T_G                           | icon_global_icosahedral_single-level_{ref_time}_{lead}_T_G.grib2.bz2                            |
# | icon    | icon/grib/06/t_ice/                  | grib      |       1 | SINGLE-LEVEL_T_ICE                         | icon_global_icosahedral_single-level_{ref_time}_{lead}_T_ICE.grib2.bz2                          |
# | icon    | icon/grib/06/t_mnw_lk/               | grib      |       1 | T_MNW_LK                                   | icon_global_icosahedral_single-level_{ref_time}_{lead}_T_MNW_LK.grib2.bz2                       |
# | icon    | icon/grib/06/t_snow/                 | grib      |       1 | SINGLE-LEVEL_T_SNOW                        | icon_global_icosahedral_single-level_{ref_time}_{lead}_T_SNOW.grib2.bz2                         |
# | icon    | icon/grib/06/t_so/                   | grib      |       2 | SOIL-LEVEL_T_SO, T_SO                      | icon_global_icosahedral_soil-level_{ref_time}_{lead}_0_T_SO.grib2.bz2                           |
# | icon    | icon/grib/06/t_wml_lk/               | grib      |       1 | T_WML_LK                                   | icon_global_icosahedral_single-level_{ref_time}_{lead}_T_WML_LK.grib2.bz2                       |
# | icon    | icon/grib/06/tch/                    | grib      |       1 | ICOSAHEDRAL_SINGLE-LEVEL_TCH               | icon_global_icosahedral_single-level_{ref_time}_{lead}_TCH.grib2.bz2                            |
# | icon    | icon/grib/06/tcm/                    | grib      |       1 | ICOSAHEDRAL_SINGLE-LEVEL_TCM               | icon_global_icosahedral_single-level_{ref_time}_{lead}_TCM.grib2.bz2                            |
# | icon    | icon/grib/06/td_2m/                  | grib      |       1 | SINGLE-LEVEL_TD_2M                         | icon_global_icosahedral_single-level_{ref_time}_{lead}_TD_2M.grib2.bz2                          |
# | icon    | icon/grib/06/tke/                    | grib      |       1 | ICOSAHEDRAL_MODEL-LEVEL_TKE                | icon_global_icosahedral_model-level_{ref_time}_{lead}_{lead}_TKE.grib2.bz2                      |
# | icon    | icon/grib/06/tmax_2m/                | grib      |       1 | SINGLE-LEVEL_TMAX_2M                       | icon_global_icosahedral_single-level_{ref_time}_{lead}_TMAX_2M.grib2.bz2                        |
# | icon    | icon/grib/06/tmin_2m/                | grib      |       1 | SINGLE-LEVEL_TMIN_2M                       | icon_global_icosahedral_single-level_{ref_time}_{lead}_TMIN_2M.grib2.bz2                        |
# | icon    | icon/grib/06/tot_prec/               | grib      |       1 | SINGLE-LEVEL_TOT_PREC                      | icon_global_icosahedral_single-level_{ref_time}_{lead}_TOT_PREC.grib2.bz2                       |
# | icon    | icon/grib/06/tqc/                    | grib      |       1 | ICOSAHEDRAL_SINGLE-LEVEL_TQC               | icon_global_icosahedral_single-level_{ref_time}_{lead}_TQC.grib2.bz2                            |
# | icon    | icon/grib/06/tqc_dia/                | grib      |       1 | SINGLE-LEVEL_TQC_DIA                       | icon_global_icosahedral_single-level_{ref_time}_{lead}_TQC_DIA.grib2.bz2                        |
# | icon    | icon/grib/06/tqi/                    | grib      |       1 | ICOSAHEDRAL_SINGLE-LEVEL_TQI               | icon_global_icosahedral_single-level_{ref_time}_{lead}_TQI.grib2.bz2                            |
# | icon    | icon/grib/06/tqi_dia/                | grib      |       1 | SINGLE-LEVEL_TQI_DIA                       | icon_global_icosahedral_single-level_{ref_time}_{lead}_TQI_DIA.grib2.bz2                        |
# | icon    | icon/grib/06/tqr/                    | grib      |       1 | ICOSAHEDRAL_SINGLE-LEVEL_TQR               | icon_global_icosahedral_single-level_{ref_time}_{lead}_TQR.grib2.bz2                            |
# | icon    | icon/grib/06/tqs/                    | grib      |       1 | ICOSAHEDRAL_SINGLE-LEVEL_TQS               | icon_global_icosahedral_single-level_{ref_time}_{lead}_TQS.grib2.bz2                            |
# | icon    | icon/grib/06/tqv/                    | grib      |       1 | ICOSAHEDRAL_SINGLE-LEVEL_TQV               | icon_global_icosahedral_single-level_{ref_time}_{lead}_TQV.grib2.bz2                            |
# | icon    | icon/grib/06/u/                      | grib      |       1 | ICOSAHEDRAL_MODEL-LEVEL_U                  | icon_global_icosahedral_model-level_{ref_time}_{lead}_{lead}_U.grib2.bz2                        |
# | icon    | icon/grib/06/u_10m/                  | grib      |       1 | SINGLE-LEVEL_U_10M                         | icon_global_icosahedral_single-level_{ref_time}_{lead}_U_{lead}M.grib2.bz2                      |
# | icon    | icon/grib/06/v/                      | grib      |       1 | ICOSAHEDRAL_MODEL-LEVEL_V                  | icon_global_icosahedral_model-level_{ref_time}_{lead}_{lead}_V.grib2.bz2                        |
# | icon    | icon/grib/06/v_10m/                  | grib      |       1 | SINGLE-LEVEL_V_10M                         | icon_global_icosahedral_single-level_{ref_time}_{lead}_V_{lead}M.grib2.bz2                      |
# | icon    | icon/grib/06/vmax_10m/               | grib      |       1 | SINGLE-LEVEL_VMAX_10M                      | icon_global_icosahedral_single-level_{ref_time}_{lead}_VMAX_{lead}M.grib2.bz2                   |
# | icon    | icon/grib/06/w/                      | grib      |       1 | ICOSAHEDRAL_MODEL-LEVEL_W                  | icon_global_icosahedral_model-level_{ref_time}_{lead}_{lead}_W.grib2.bz2                        |
# | icon    | icon/grib/06/w_i/                    | grib      |       1 | SINGLE-LEVEL_W_I                           | icon_global_icosahedral_single-level_{ref_time}_{lead}_W_I.grib2.bz2                            |
# | icon    | icon/grib/06/w_snow/                 | grib      |       1 | SINGLE-LEVEL_W_SNOW                        | icon_global_icosahedral_single-level_{ref_time}_{lead}_W_SNOW.grib2.bz2                         |
# | icon    | icon/grib/06/w_so/                   | grib      |       2 | SOIL-LEVEL_W_SO, W_SO                      | icon_global_icosahedral_soil-level_{ref_time}_{lead}_0_W_SO.grib2.bz2                           |
# | icon    | icon/grib/06/w_so_ice/               | grib      |       1 | W_SO_ICE                                   | icon_global_icosahedral_soil-level_{ref_time}_{lead}_0_W_SO_ICE.grib2.bz2                       |
# | icon    | icon/grib/06/ww/                     | grib      |       1 | ICOSAHEDRAL_SINGLE-LEVEL_WW                | icon_global_icosahedral_single-level_{ref_time}_{lead}_WW.grib2.bz2                             |
# | icon    | icon/grib/06/z0/                     | grib      |       1 | ICOSAHEDRAL_SINGLE-LEVEL_Z0                | icon_global_icosahedral_single-level_{ref_time}_{lead}_Z0.grib2.bz2                             |
# | icon    | icon/grib/12/alb_rad/                | grib      |       1 | SINGLE-LEVEL_ALB_RAD                       | icon_global_icosahedral_single-level_{ref_time}_{lead}_ALB_RAD.grib2.bz2                        |
# | icon    | icon/grib/12/alb_seaice/             | grib      |       1 | TIME-INVARIANT_ALB_SEAICE                  | icon_global_icosahedral_time-invariant_{ref_time}_ALB_SEAICE.grib2.bz2                          |
# | icon    | icon/grib/12/alhfl_s/                | grib      |       1 | SINGLE-LEVEL_ALHFL_S                       | icon_global_icosahedral_single-level_{ref_time}_{lead}_ALHFL_S.grib2.bz2                        |
# | icon    | icon/grib/12/ashfl_s/                | grib      |       1 | SINGLE-LEVEL_ASHFL_S                       | icon_global_icosahedral_single-level_{ref_time}_{lead}_ASHFL_S.grib2.bz2                        |
# | icon    | icon/grib/12/asob_s/                 | grib      |       1 | SINGLE-LEVEL_ASOB_S                        | icon_global_icosahedral_single-level_{ref_time}_{lead}_ASOB_S.grib2.bz2                         |
# | icon    | icon/grib/12/asob_s_cs/              | grib      |       1 | ASOB_S_CS                                  | icon_global_icosahedral_single-level_{ref_time}_{lead}_ASOB_S_CS.grib2.bz2                      |
# | icon    | icon/grib/12/asob_t/                 | grib      |       1 | SINGLE-LEVEL_ASOB_T                        | icon_global_icosahedral_single-level_{ref_time}_{lead}_ASOB_T.grib2.bz2                         |
# | icon    | icon/grib/12/aswdifd_s/              | grib      |       1 | SINGLE-LEVEL_ASWDIFD_S                     | icon_global_icosahedral_single-level_{ref_time}_{lead}_ASWDIFD_S.grib2.bz2                      |
# | icon    | icon/grib/12/aswdifu_s/              | grib      |       1 | SINGLE-LEVEL_ASWDIFU_S                     | icon_global_icosahedral_single-level_{ref_time}_{lead}_ASWDIFU_S.grib2.bz2                      |
# | icon    | icon/grib/12/aswdir_s/               | grib      |       1 | SINGLE-LEVEL_ASWDIR_S                      | icon_global_icosahedral_single-level_{ref_time}_{lead}_ASWDIR_S.grib2.bz2                       |
# | icon    | icon/grib/12/athb_s/                 | grib      |       1 | SINGLE-LEVEL_ATHB_S                        | icon_global_icosahedral_single-level_{ref_time}_{lead}_ATHB_S.grib2.bz2                         |
# | icon    | icon/grib/12/athb_t/                 | grib      |       1 | SINGLE-LEVEL_ATHB_T                        | icon_global_icosahedral_single-level_{ref_time}_{lead}_ATHB_T.grib2.bz2                         |
# | icon    | icon/grib/12/aumfl_s/                | grib      |       1 | SINGLE-LEVEL_AUMFL_S                       | icon_global_icosahedral_single-level_{ref_time}_{lead}_AUMFL_S.grib2.bz2                        |
# ...
# | icon-eu | icon-eu/grib/21/clct/                | grib      |       1 | REGULAR-LAT-LON_SINGLE-LEVEL_CLCT          | icon-eu_europe_regular-lat-lon_single-level_{ref_time}_{lead}_CLCT.grib2.bz2                    |
# | icon-eu | icon-eu/grib/21/clct_mod/            | grib      |       1 | SINGLE-LEVEL_CLCT_MOD                      | icon-eu_europe_regular-lat-lon_single-level_{ref_time}_{lead}_CLCT_MOD.grib2.bz2                |
# | icon-eu | icon-eu/grib/21/cldepth/             | grib      |       1 | REGULAR-LAT-LON_SINGLE-LEVEL_CLDEPTH       | icon-eu_europe_regular-lat-lon_single-level_{ref_time}_{lead}_CLDEPTH.grib2.bz2                 |
# | icon-eu | icon-eu/grib/21/depth_lk/            | grib      |       1 | TIME-INVARIANT_DEPTH_LK                    | icon-eu_europe_regular-lat-lon_time-invariant_{ref_time}_DEPTH_LK.grib2.bz2                     |
# | icon-eu | icon-eu/grib/21/fi/                  | grib      |       1 | REGULAR-LAT-LON_PRESSURE-LEVEL_FI          | icon-eu_europe_regular-lat-lon_pressure-level_{ref_time}_{lead}_{lead}_FI.grib2.bz2             |
# | icon-eu | icon-eu/grib/21/fr_lake/             | grib      |       1 | TIME-INVARIANT_FR_LAKE                     | icon-eu_europe_regular-lat-lon_time-invariant_{ref_time}_FR_LAKE.grib2.bz2                      |
# | icon-eu | icon-eu/grib/21/fr_land/             | grib      |       1 | TIME-INVARIANT_FR_LAND                     | icon-eu_europe_regular-lat-lon_time-invariant_{ref_time}_FR_LAND.grib2.bz2                      |
# | icon-eu | icon-eu/grib/21/h_ice/               | grib      |       1 | SINGLE-LEVEL_H_ICE                         | icon-eu_europe_regular-lat-lon_single-level_{ref_time}_{lead}_H_ICE.grib2.bz2                   |
# | icon-eu | icon-eu/grib/21/h_snow/              | grib      |       1 | SINGLE-LEVEL_H_SNOW                        | icon-eu_europe_regular-lat-lon_single-level_{ref_time}_{lead}_H_SNOW.grib2.bz2                  |
# | icon-eu | icon-eu/grib/21/hbas_con/            | grib      |       1 | SINGLE-LEVEL_HBAS_CON                      | icon-eu_europe_regular-lat-lon_single-level_{ref_time}_{lead}_HBAS_CON.grib2.bz2                |
# | icon-eu | icon-eu/grib/21/hhl/                 | grib      |       1 | REGULAR-LAT-LON_TIME-INVARIANT_HHL         | icon-eu_europe_regular-lat-lon_time-invariant_{ref_time}_{lead}_HHL.grib2.bz2                   |
# | icon-eu | icon-eu/grib/21/hsurf/               | grib      |       1 | REGULAR-LAT-LON_TIME-INVARIANT_HSURF       | icon-eu_europe_regular-lat-lon_time-invariant_{ref_time}_HSURF.grib2.bz2                        |
# | icon-eu | icon-eu/grib/21/htop_con/            | grib      |       1 | SINGLE-LEVEL_HTOP_CON                      | icon-eu_europe_regular-lat-lon_single-level_{ref_time}_{lead}_HTOP_CON.grib2.bz2                |
# | icon-eu | icon-eu/grib/21/htop_dc/             | grib      |       1 | SINGLE-LEVEL_HTOP_DC                       | icon-eu_europe_regular-lat-lon_single-level_{ref_time}_{lead}_HTOP_DC.grib2.bz2                 |
# | icon-eu | icon-eu/grib/21/hzerocl/             | grib      |       1 | REGULAR-LAT-LON_SINGLE-LEVEL_HZEROCL       | icon-eu_europe_regular-lat-lon_single-level_{ref_time}_{lead}_HZEROCL.grib2.bz2                 |
# | icon-eu | icon-eu/grib/21/lai/                 | grib      |       1 | REGULAR-LAT-LON_TIME-INVARIANT_LAI         | icon-eu_europe_regular-lat-lon_time-invariant_{ref_time}_LAI.grib2.bz2                          |
# | icon-eu | icon-eu/grib/21/lpi_con_max/         | grib      |       1 | LPI_CON_MAX                                | icon-eu_europe_regular-lat-lon_single-level_{ref_time}_{lead}_LPI_CON_MAX.grib2.bz2             |
# | icon-eu | icon-eu/grib/21/mh/                  | grib      |       1 | REGULAR-LAT-LON_SINGLE-LEVEL_MH            | icon-eu_europe_regular-lat-lon_single-level_{ref_time}_{lead}_MH.grib2.bz2                      |
# | icon-eu | icon-eu/grib/21/omega/               | grib      |       1 | REGULAR-LAT-LON_PRESSURE-LEVEL_OMEGA       | icon-eu_europe_regular-lat-lon_pressure-level_{ref_time}_{lead}_{lead}_OMEGA.grib2.bz2          |
# | icon-eu | icon-eu/grib/21/p/                   | grib      |       1 | REGULAR-LAT-LON_MODEL-LEVEL_P              | icon-eu_europe_regular-lat-lon_model-level_{ref_time}_{lead}_{lead}_P.grib2.bz2                 |
# | icon-eu | icon-eu/grib/21/plcov/               | grib      |       1 | REGULAR-LAT-LON_TIME-INVARIANT_PLCOV       | icon-eu_europe_regular-lat-lon_time-invariant_{ref_time}_PLCOV.grib2.bz2                        |
# | icon-eu | icon-eu/grib/21/pmsl/                | grib      |       1 | REGULAR-LAT-LON_SINGLE-LEVEL_PMSL          | icon-eu_europe_regular-lat-lon_single-level_{ref_time}_{lead}_PMSL.grib2.bz2                    |
# | icon-eu | icon-eu/grib/21/ps/                  | grib      |       1 | REGULAR-LAT-LON_SINGLE-LEVEL_PS            | icon-eu_europe_regular-lat-lon_single-level_{ref_time}_{lead}_PS.grib2.bz2                      |
# | icon-eu | icon-eu/grib/21/qc/                  | grib      |       1 | REGULAR-LAT-LON_MODEL-LEVEL_QC             | icon-eu_europe_regular-lat-lon_model-level_{ref_time}_{lead}_{lead}_QC.grib2.bz2                |
# | icon-eu | icon-eu/grib/21/qi/                  | grib      |       1 | REGULAR-LAT-LON_MODEL-LEVEL_QI             | icon-eu_europe_regular-lat-lon_model-level_{ref_time}_{lead}_{lead}_QI.grib2.bz2                |
# | icon-eu | icon-eu/grib/21/qv/                  | grib      |       1 | REGULAR-LAT-LON_MODEL-LEVEL_QV             | icon-eu_europe_regular-lat-lon_model-level_{ref_time}_{lead}_{lead}_QV.grib2.bz2                |
# | icon-eu | icon-eu/grib/21/qv_2m/               | grib      |       1 | SINGLE-LEVEL_QV_2M                         | icon-eu_europe_regular-lat-lon_single-level_{ref_time}_{lead}_QV_2M.grib2.bz2                   |
# | icon-eu | icon-eu/grib/21/qv_s/                | grib      |       1 | SINGLE-LEVEL_QV_S                          | icon-eu_europe_regular-lat-lon_single-level_{ref_time}_{lead}_QV_S.grib2.bz2                    |
# | icon-eu | icon-eu/grib/21/rain_con/            | grib      |       1 | SINGLE-LEVEL_RAIN_CON                      | icon-eu_europe_regular-lat-lon_single-level_{ref_time}_{lead}_RAIN_CON.grib2.bz2                |
# | icon-eu | icon-eu/grib/21/rain_gsp/            | grib      |       1 | SINGLE-LEVEL_RAIN_GSP                      | icon-eu_europe_regular-lat-lon_single-level_{ref_time}_{lead}_RAIN_GSP.grib2.bz2                |
# | icon-eu | icon-eu/grib/21/relhum/              | grib      |       1 | REGULAR-LAT-LON_PRESSURE-LEVEL_RELHUM      | icon-eu_europe_regular-lat-lon_pressure-level_{ref_time}_{lead}_{lead}_RELHUM.grib2.bz2         |
# | icon-eu | icon-eu/grib/21/relhum_2m/           | grib      |       1 | SINGLE-LEVEL_RELHUM_2M                     | icon-eu_europe_regular-lat-lon_single-level_{ref_time}_{lead}_RELHUM_2M.grib2.bz2               |
# | icon-eu | icon-eu/grib/21/rho_snow/            | grib      |       1 | SINGLE-LEVEL_RHO_SNOW                      | icon-eu_europe_regular-lat-lon_single-level_{ref_time}_{lead}_RHO_SNOW.grib2.bz2                |
# | icon-eu | icon-eu/grib/21/rlat/                | grib      |       1 | REGULAR-LAT-LON_TIME-INVARIANT_RLAT        | icon-eu_europe_regular-lat-lon_time-invariant_{ref_time}_RLAT.grib2.bz2                         |
# | icon-eu | icon-eu/grib/21/rlon/                | grib      |       1 | REGULAR-LAT-LON_TIME-INVARIANT_RLON        | icon-eu_europe_regular-lat-lon_time-invariant_{ref_time}_RLON.grib2.bz2                         |
# | icon-eu | icon-eu/grib/21/rootdp/              | grib      |       1 | REGULAR-LAT-LON_TIME-INVARIANT_ROOTDP      | icon-eu_europe_regular-lat-lon_time-invariant_{ref_time}_ROOTDP.grib2.bz2                       |
# | icon-eu | icon-eu/grib/21/runoff_g/            | grib      |       1 | SINGLE-LEVEL_RUNOFF_G                      | icon-eu_europe_regular-lat-lon_single-level_{ref_time}_{lead}_RUNOFF_G.grib2.bz2                |
# | icon-eu | icon-eu/grib/21/runoff_s/            | grib      |       1 | SINGLE-LEVEL_RUNOFF_S                      | icon-eu_europe_regular-lat-lon_single-level_{ref_time}_{lead}_RUNOFF_S.grib2.bz2                |
# | icon-eu | icon-eu/grib/21/snow_con/            | grib      |       1 | SINGLE-LEVEL_SNOW_CON                      | icon-eu_europe_regular-lat-lon_single-level_{ref_time}_{lead}_SNOW_CON.grib2.bz2                |
# | icon-eu | icon-eu/grib/21/snow_gsp/            | grib      |       1 | SINGLE-LEVEL_SNOW_GSP                      | icon-eu_europe_regular-lat-lon_single-level_{ref_time}_{lead}_SNOW_GSP.grib2.bz2                |
# | icon-eu | icon-eu/grib/21/snowlmt/             | grib      |       1 | REGULAR-LAT-LON_SINGLE-LEVEL_SNOWLMT       | icon-eu_europe_regular-lat-lon_single-level_{ref_time}_{lead}_SNOWLMT.grib2.bz2                 |
# | icon-eu | icon-eu/grib/21/soiltyp/             | grib      |       1 | REGULAR-LAT-LON_TIME-INVARIANT_SOILTYP     | icon-eu_europe_regular-lat-lon_time-invariant_{ref_time}_SOILTYP.grib2.bz2                      |
# | icon-eu | icon-eu/grib/21/synmsg_bt_cl_ir10.8/ | grib      |       1 | BT_CL_IR10.8                               | icon-eu_europe_regular-lat-lon_single-level_{ref_time}_{lead}_SYNMSG_BT_CL_IR{lead}.8.grib2.bz2 |
# | icon-eu | icon-eu/grib/21/synmsg_bt_cl_wv6.2/  | grib      |       1 | BT_CL_WV6.2                                | icon-eu_europe_regular-lat-lon_single-level_{ref_time}_{lead}_SYNMSG_BT_CL_WV6.2.grib2.bz2      |
# | icon-eu | icon-eu/grib/21/t/                   | grib      |       1 | REGULAR-LAT-LON_MODEL-LEVEL_T              | icon-eu_europe_regular-lat-lon_model-level_{ref_time}_{lead}_{lead}_T.grib2.bz2                 |
# | icon-eu | icon-eu/grib/21/t_2m/                | grib      |       1 | SINGLE-LEVEL_T_2M                          | icon-eu_europe_regular-lat-lon_single-level_{ref_time}_{lead}_T_2M.grib2.bz2                    |
# | icon-eu | icon-eu/grib/21/t_g/                 | grib      |       1 | SINGLE-LEVEL_T_G                           | icon-eu_europe_regular-lat-lon_single-level_{ref_time}_{lead}_T_G.grib2.bz2                     |
# | icon-eu | icon-eu/grib/21/t_ice/               | grib      |       1 | SINGLE-LEVEL_T_ICE                         | icon-eu_europe_regular-lat-lon_single-level_{ref_time}_{lead}_T_ICE.grib2.bz2                   |
# | icon-eu | icon-eu/grib/21/t_snow/              | grib      |       1 | SINGLE-LEVEL_T_SNOW                        | icon-eu_europe_regular-lat-lon_single-level_{ref_time}_{lead}_T_SNOW.grib2.bz2                  |
# | icon-eu | icon-eu/grib/21/t_so/                | grib      |       2 | SOIL-LEVEL_T_SO, T_SO                      | icon-eu_europe_regular-lat-lon_soil-level_{ref_time}_{lead}_0_T_SO.grib2.bz2                    |
# | icon-eu | icon-eu/grib/21/tch/                 | grib      |       1 | REGULAR-LAT-LON_SINGLE-LEVEL_TCH           | icon-eu_europe_regular-lat-lon_single-level_{ref_time}_{lead}_TCH.grib2.bz2                     |
# | icon-eu | icon-eu/grib/21/tcm/                 | grib      |       1 | REGULAR-LAT-LON_SINGLE-LEVEL_TCM           | icon-eu_europe_regular-lat-lon_single-level_{ref_time}_{lead}_TCM.grib2.bz2                     |
# | icon-eu | icon-eu/grib/21/td_2m/               | grib      |       1 | SINGLE-LEVEL_TD_2M                         | icon-eu_europe_regular-lat-lon_single-level_{ref_time}_{lead}_TD_2M.grib2.bz2                   |
# | icon-eu | icon-eu/grib/21/tke/                 | grib      |       1 | REGULAR-LAT-LON_MODEL-LEVEL_TKE            | icon-eu_europe_regular-lat-lon_model-level_{ref_time}_{lead}_{lead}_TKE.grib2.bz2               |
# | icon-eu | icon-eu/grib/21/tmax_2m/             | grib      |       1 | SINGLE-LEVEL_TMAX_2M                       | icon-eu_europe_regular-lat-lon_single-level_{ref_time}_{lead}_TMAX_2M.grib2.bz2                 |
# | icon-eu | icon-eu/grib/21/tmin_2m/             | grib      |       1 | SINGLE-LEVEL_TMIN_2M                       | icon-eu_europe_regular-lat-lon_single-level_{ref_time}_{lead}_TMIN_2M.grib2.bz2                 |
# | icon-eu | icon-eu/grib/21/tot_prec/            | grib      |       1 | SINGLE-LEVEL_TOT_PREC                      | icon-eu_europe_regular-lat-lon_single-level_{ref_time}_{lead}_TOT_PREC.grib2.bz2                |
# | icon-eu | icon-eu/grib/21/tqc/                 | grib      |       1 | REGULAR-LAT-LON_SINGLE-LEVEL_TQC           | icon-eu_europe_regular-lat-lon_single-level_{ref_time}_{lead}_TQC.grib2.bz2                     |
# | icon-eu | icon-eu/grib/21/tqi/                 | grib      |       1 | REGULAR-LAT-LON_SINGLE-LEVEL_TQI           | icon-eu_europe_regular-lat-lon_single-level_{ref_time}_{lead}_TQI.grib2.bz2                     |
# | icon-eu | icon-eu/grib/21/tqr/                 | grib      |       1 | REGULAR-LAT-LON_SINGLE-LEVEL_TQR           | icon-eu_europe_regular-lat-lon_single-level_{ref_time}_{lead}_TQR.grib2.bz2                     |
# | icon-eu | icon-eu/grib/21/tqs/                 | grib      |       1 | REGULAR-LAT-LON_SINGLE-LEVEL_TQS           | icon-eu_europe_regular-lat-lon_single-level_{ref_time}_{lead}_TQS.grib2.bz2                     |
# | icon-eu | icon-eu/grib/21/tqv/                 | grib      |       1 | REGULAR-LAT-LON_SINGLE-LEVEL_TQV           | icon-eu_europe_regular-lat-lon_single-level_{ref_time}_{lead}_TQV.grib2.bz2                     |
# | icon-eu | icon-eu/grib/21/u/                   | grib      |       1 | REGULAR-LAT-LON_MODEL-LEVEL_U              | icon-eu_europe_regular-lat-lon_model-level_{ref_time}_{lead}_{lead}_U.grib2.bz2                 |
# | icon-eu | icon-eu/grib/21/u_10m/               | grib      |       1 | SINGLE-LEVEL_U_10M                         | icon-eu_europe_regular-lat-lon_single-level_{ref_time}_{lead}_U_{lead}M.grib2.bz2               |
# | icon-eu | icon-eu/grib/21/v/                   | grib      |       1 | REGULAR-LAT-LON_MODEL-LEVEL_V              | icon-eu_europe_regular-lat-lon_model-level_{ref_time}_{lead}_{lead}_V.grib2.bz2                 |
# | icon-eu | icon-eu/grib/21/v_10m/               | grib      |       1 | SINGLE-LEVEL_V_10M                         | icon-eu_europe_regular-lat-lon_single-level_{ref_time}_{lead}_V_{lead}M.grib2.bz2               |
# | icon-eu | icon-eu/grib/21/vis/                 | grib      |       1 | REGULAR-LAT-LON_SINGLE-LEVEL_VIS           | icon-eu_europe_regular-lat-lon_single-level_{ref_time}_{lead}_VIS.grib2.bz2                     |
# | icon-eu | icon-eu/grib/21/vmax_10m/            | grib      |       1 | SINGLE-LEVEL_VMAX_10M                      | icon-eu_europe_regular-lat-lon_single-level_{ref_time}_{lead}_VMAX_{lead}M.grib2.bz2            |
# | icon-eu | icon-eu/grib/21/w/                   | grib      |       1 | REGULAR-LAT-LON_MODEL-LEVEL_W              | icon-eu_europe_regular-lat-lon_model-level_{ref_time}_{lead}_{lead}_W.grib2.bz2                 |
# | icon-eu | icon-eu/grib/21/w_snow/              | grib      |       1 | SINGLE-LEVEL_W_SNOW                        | icon-eu_europe_regular-lat-lon_single-level_{ref_time}_{lead}_W_SNOW.grib2.bz2                  |
# | icon-eu | icon-eu/grib/21/w_so/                | grib      |       2 | SOIL-LEVEL_W_SO, W_SO                      | icon-eu_europe_regular-lat-lon_soil-level_{ref_time}_{lead}_0_W_SO.grib2.bz2                    |
# | icon-eu | icon-eu/grib/21/w_so_ice/            | grib      |       1 | W_SO_ICE                                   | icon-eu_europe_regular-lat-lon_soil-level_{ref_time}_{lead}_0_W_SO_ICE.grib2.bz2                |
# | icon-eu | icon-eu/grib/21/ww/                  | grib      |       1 | REGULAR-LAT-LON_SINGLE-LEVEL_WW            | icon-eu_europe_regular-lat-lon_single-level_{ref_time}_{lead}_WW.grib2.bz2                      |
# | icon-eu | icon-eu/grib/21/z0/                  | grib      |       1 | REGULAR-LAT-LON_SINGLE-LEVEL_Z0            | icon-eu_europe_regular-lat-lon_single-level_{ref_time}_{lead}_Z0.grib2.bz2                      |

# %%
def classify_product(product_dir: str):
    p = product_dir.lower()

    if "single-level" in p or "/00/" in p:
        level = "single-level"
    elif "model-level" in p:
        level = "model-level"
    elif "pressure-level" in p:
        level = "pressure-level"
    else:
        level = "unknown"

    if "icosa" in p:
        grid = "icosahedral"
    elif "lat-lon" in p:
        grid = "lat-lon"
    else:
        grid = "unknown"

    return level, grid

# %%
# ---------- build human-readable markdown table ----------
rows = []

for m in MODELS:
    md = inventory["models"][m]
    for p in md["products"]:
        vars_ = p.get("variables", [])
        templs = p.get("templates", [])

        rows.append({
            "model": m,
            "product_dir": p["product_dir"].replace(BASE_ROOT, ""),
            "formats": ", ".join(p.get("formats", [])),
            "#vars": len(vars_),
            "vars (sample)": ", ".join(vars_[:10]) + (" …" if len(vars_) > 10 else ""),
            "template (sample)": templs[0] if templs else "",
        })

df = pd.DataFrame(rows)

# Sort for readability
if not df.empty:
    df = df.sort_values(["model", "product_dir"]).reset_index(drop=True)

print("\n--- Human-readable summary (Markdown) ---\n")
print(df.to_markdown(index=False))
# Out:
# --- Human-readable summary (Markdown) ---
#
# | model   | product_dir                          | formats   |   #vars | vars (sample)                              | template (sample)                                                                               |
# |:--------|:-------------------------------------|:----------|--------:|:-------------------------------------------|:------------------------------------------------------------------------------------------------|
# | icon    | icon/grib/00/alb_rad/                | grib      |       1 | SINGLE-LEVEL_ALB_RAD                       | icon_global_icosahedral_single-level_{ref_time}_{lead}_ALB_RAD.grib2.bz2                        |
# | icon    | icon/grib/00/alb_seaice/             | grib      |       1 | TIME-INVARIANT_ALB_SEAICE                  | icon_global_icosahedral_time-invariant_{ref_time}_ALB_SEAICE.grib2.bz2                          |
# | icon    | icon/grib/00/alhfl_s/                | grib      |       1 | SINGLE-LEVEL_ALHFL_S                       | icon_global_icosahedral_single-level_{ref_time}_{lead}_ALHFL_S.grib2.bz2                        |
# | icon    | icon/grib/00/ashfl_s/                | grib      |       1 | SINGLE-LEVEL_ASHFL_S                       | icon_global_icosahedral_single-level_{ref_time}_{lead}_ASHFL_S.grib2.bz2                        |
# | icon    | icon/grib/00/asob_s/                 | grib      |       1 | SINGLE-LEVEL_ASOB_S                        | icon_global_icosahedral_single-level_{ref_time}_{lead}_ASOB_S.grib2.bz2                         |
# | icon    | icon/grib/00/asob_s_cs/              | grib      |       1 | ASOB_S_CS                                  | icon_global_icosahedral_single-level_{ref_time}_{lead}_ASOB_S_CS.grib2.bz2                      |
# | icon    | icon/grib/00/asob_t/                 | grib      |       1 | SINGLE-LEVEL_ASOB_T                        | icon_global_icosahedral_single-level_{ref_time}_{lead}_ASOB_T.grib2.bz2                         |
# | icon    | icon/grib/00/aswdifd_s/              | grib      |       1 | SINGLE-LEVEL_ASWDIFD_S                     | icon_global_icosahedral_single-level_{ref_time}_{lead}_ASWDIFD_S.grib2.bz2                      |
# | icon    | icon/grib/00/aswdifu_s/              | grib      |       1 | SINGLE-LEVEL_ASWDIFU_S                     | icon_global_icosahedral_single-level_{ref_time}_{lead}_ASWDIFU_S.grib2.bz2                      |
# | icon    | icon/grib/00/aswdir_s/               | grib      |       1 | SINGLE-LEVEL_ASWDIR_S                      | icon_global_icosahedral_single-level_{ref_time}_{lead}_ASWDIR_S.grib2.bz2                       |
# | icon    | icon/grib/00/athb_s/                 | grib      |       1 | SINGLE-LEVEL_ATHB_S                        | icon_global_icosahedral_single-level_{ref_time}_{lead}_ATHB_S.grib2.bz2                         |
# | icon    | icon/grib/00/athb_t/                 | grib      |       1 | SINGLE-LEVEL_ATHB_T                        | icon_global_icosahedral_single-level_{ref_time}_{lead}_ATHB_T.grib2.bz2                         |
# | icon    | icon/grib/00/aumfl_s/                | grib      |       1 | SINGLE-LEVEL_AUMFL_S                       | icon_global_icosahedral_single-level_{ref_time}_{lead}_AUMFL_S.grib2.bz2                        |
# | icon    | icon/grib/00/avmfl_s/                | grib      |       1 | SINGLE-LEVEL_AVMFL_S                       | icon_global_icosahedral_single-level_{ref_time}_{lead}_AVMFL_S.grib2.bz2                        |
# | icon    | icon/grib/00/c_t_lk/                 | grib      |       1 | C_T_LK                                     | icon_global_icosahedral_single-level_{ref_time}_{lead}_C_T_LK.grib2.bz2                         |
# | icon    | icon/grib/00/cape_con/               | grib      |       1 | SINGLE-LEVEL_CAPE_CON                      | icon_global_icosahedral_single-level_{ref_time}_{lead}_CAPE_CON.grib2.bz2                       |
# | icon    | icon/grib/00/cape_ml/                | grib      |       1 | SINGLE-LEVEL_CAPE_ML                       | icon_global_icosahedral_single-level_{ref_time}_{lead}_CAPE_ML.grib2.bz2                        |
# | icon    | icon/grib/00/clat/                   | grib      |       1 | ICOSAHEDRAL_TIME-INVARIANT_CLAT            | icon_global_icosahedral_time-invariant_{ref_time}_CLAT.grib2.bz2                                |
# | icon    | icon/grib/00/clc/                    | grib      |       1 | ICOSAHEDRAL_MODEL-LEVEL_CLC                | icon_global_icosahedral_model-level_{ref_time}_{lead}_{lead}_CLC.grib2.bz2                      |
# | icon    | icon/grib/00/clch/                   | grib      |       1 | ICOSAHEDRAL_SINGLE-LEVEL_CLCH              | icon_global_icosahedral_single-level_{ref_time}_{lead}_CLCH.grib2.bz2                           |
# | icon    | icon/grib/00/clcl/                   | grib      |       1 | ICOSAHEDRAL_SINGLE-LEVEL_CLCL              | icon_global_icosahedral_single-level_{ref_time}_{lead}_CLCL.grib2.bz2                           |
# | icon    | icon/grib/00/clcm/                   | grib      |       1 | ICOSAHEDRAL_SINGLE-LEVEL_CLCM              | icon_global_icosahedral_single-level_{ref_time}_{lead}_CLCM.grib2.bz2                           |
# | icon    | icon/grib/00/clct/                   | grib      |       1 | ICOSAHEDRAL_SINGLE-LEVEL_CLCT              | icon_global_icosahedral_single-level_{ref_time}_{lead}_CLCT.grib2.bz2                           |
# | icon    | icon/grib/00/clct_mod/               | grib      |       1 | SINGLE-LEVEL_CLCT_MOD                      | icon_global_icosahedral_single-level_{ref_time}_{lead}_CLCT_MOD.grib2.bz2                       |
# | icon    | icon/grib/00/cldepth/                | grib      |       1 | ICOSAHEDRAL_SINGLE-LEVEL_CLDEPTH           | icon_global_icosahedral_single-level_{ref_time}_{lead}_CLDEPTH.grib2.bz2                        |
# | icon    | icon/grib/00/clon/                   | grib      |       1 | ICOSAHEDRAL_TIME-INVARIANT_CLON            | icon_global_icosahedral_time-invariant_{ref_time}_CLON.grib2.bz2                                |
# | icon    | icon/grib/00/depth_lk/               | grib      |       1 | TIME-INVARIANT_DEPTH_LK                    | icon_global_icosahedral_time-invariant_{ref_time}_DEPTH_LK.grib2.bz2                            |
# | icon    | icon/grib/00/elat/                   | grib      |       1 | ICOSAHEDRAL_TIME-INVARIANT_ELAT            | icon_global_icosahedral_time-invariant_{ref_time}_ELAT.grib2.bz2                                |
# | icon    | icon/grib/00/elon/                   | grib      |       1 | ICOSAHEDRAL_TIME-INVARIANT_ELON            | icon_global_icosahedral_time-invariant_{ref_time}_ELON.grib2.bz2                                |
# | icon    | icon/grib/00/evap_pl/                | grib      |       1 | TIME-INVARIANT_EVAP_PL                     | icon_global_icosahedral_time-invariant_{ref_time}_EVAP_PL.grib2.bz2                             |
# | icon    | icon/grib/00/fi/                     | grib      |       1 | ICOSAHEDRAL_PRESSURE-LEVEL_FI              | icon_global_icosahedral_pressure-level_{ref_time}_{lead}_{lead}_FI.grib2.bz2                    |
# | icon    | icon/grib/00/fr_ice/                 | grib      |       1 | SINGLE-LEVEL_FR_ICE                        | icon_global_icosahedral_single-level_{ref_time}_{lead}_FR_ICE.grib2.bz2                         |
# | icon    | icon/grib/00/fr_lake/                | grib      |       1 | TIME-INVARIANT_FR_LAKE                     | icon_global_icosahedral_time-invariant_{ref_time}_FR_LAKE.grib2.bz2                             |
# | icon    | icon/grib/00/fr_land/                | grib      |       1 | TIME-INVARIANT_FR_LAND                     | icon_global_icosahedral_time-invariant_{ref_time}_FR_LAND.grib2.bz2                             |
# | icon    | icon/grib/00/freshsnw/               | grib      |       1 | ICOSAHEDRAL_SINGLE-LEVEL_FRESHSNW          | icon_global_icosahedral_single-level_{ref_time}_{lead}_FRESHSNW.grib2.bz2                       |
# | icon    | icon/grib/00/h_ice/                  | grib      |       1 | SINGLE-LEVEL_H_ICE                         | icon_global_icosahedral_single-level_{ref_time}_{lead}_H_ICE.grib2.bz2                          |
# | icon    | icon/grib/00/h_ml_lk/                | grib      |       1 | H_ML_LK                                    | icon_global_icosahedral_single-level_{ref_time}_{lead}_H_ML_LK.grib2.bz2                        |
# | icon    | icon/grib/00/h_snow/                 | grib      |       1 | SINGLE-LEVEL_H_SNOW                        | icon_global_icosahedral_single-level_{ref_time}_{lead}_H_SNOW.grib2.bz2                         |
# | icon    | icon/grib/00/hbas_con/               | grib      |       1 | SINGLE-LEVEL_HBAS_CON                      | icon_global_icosahedral_single-level_{ref_time}_{lead}_HBAS_CON.grib2.bz2                       |
# | icon    | icon/grib/00/hhl/                    | grib      |       1 | ICOSAHEDRAL_TIME-INVARIANT_HHL             | icon_global_icosahedral_time-invariant_{ref_time}_{lead}_HHL.grib2.bz2                          |
# | icon    | icon/grib/00/hsnow_max/              | grib      |       1 | TIME-INVARIANT_HSNOW_MAX                   | icon_global_icosahedral_time-invariant_{ref_time}_HSNOW_MAX.grib2.bz2                           |
# | icon    | icon/grib/00/hsurf/                  | grib      |       1 | ICOSAHEDRAL_TIME-INVARIANT_HSURF           | icon_global_icosahedral_time-invariant_{ref_time}_HSURF.grib2.bz2                               |
# | icon    | icon/grib/00/htop_con/               | grib      |       1 | SINGLE-LEVEL_HTOP_CON                      | icon_global_icosahedral_single-level_{ref_time}_{lead}_HTOP_CON.grib2.bz2                       |
# | icon    | icon/grib/00/htop_dc/                | grib      |       1 | SINGLE-LEVEL_HTOP_DC                       | icon_global_icosahedral_single-level_{ref_time}_{lead}_HTOP_DC.grib2.bz2                        |
# | icon    | icon/grib/00/hzerocl/                | grib      |       1 | ICOSAHEDRAL_SINGLE-LEVEL_HZEROCL           | icon_global_icosahedral_single-level_{ref_time}_{lead}_HZEROCL.grib2.bz2                        |
# | icon    | icon/grib/00/lai/                    | grib      |       1 | ICOSAHEDRAL_TIME-INVARIANT_LAI             | icon_global_icosahedral_time-invariant_{ref_time}_LAI.grib2.bz2                                 |
# | icon    | icon/grib/00/ndviratio/              | grib      |       1 | ICOSAHEDRAL_TIME-INVARIANT_NDVIRATIO       | icon_global_icosahedral_time-invariant_{ref_time}_NDVIRATIO.grib2.bz2                           |
# | icon    | icon/grib/00/p/                      | grib      |       1 | ICOSAHEDRAL_MODEL-LEVEL_P                  | icon_global_icosahedral_model-level_{ref_time}_{lead}_{lead}_P.grib2.bz2                        |
# | icon    | icon/grib/00/plcov/                  | grib      |       1 | ICOSAHEDRAL_TIME-INVARIANT_PLCOV           | icon_global_icosahedral_time-invariant_{ref_time}_PLCOV.grib2.bz2                               |
# | icon    | icon/grib/00/pmsl/                   | grib      |       1 | ICOSAHEDRAL_SINGLE-LEVEL_PMSL              | icon_global_icosahedral_single-level_{ref_time}_{lead}_PMSL.grib2.bz2                           |
# | icon    | icon/grib/00/ps/                     | grib      |       1 | ICOSAHEDRAL_SINGLE-LEVEL_PS                | icon_global_icosahedral_single-level_{ref_time}_{lead}_PS.grib2.bz2                             |
# | icon    | icon/grib/00/qc/                     | grib      |       1 | ICOSAHEDRAL_MODEL-LEVEL_QC                 | icon_global_icosahedral_model-level_{ref_time}_{lead}_{lead}_QC.grib2.bz2                       |
# | icon    | icon/grib/00/qi/                     | grib      |       1 | ICOSAHEDRAL_MODEL-LEVEL_QI                 | icon_global_icosahedral_model-level_{ref_time}_{lead}_{lead}_QI.grib2.bz2                       |
# | icon    | icon/grib/00/qv/                     | grib      |       1 | ICOSAHEDRAL_MODEL-LEVEL_QV                 | icon_global_icosahedral_model-level_{ref_time}_{lead}_{lead}_QV.grib2.bz2                       |
# | icon    | icon/grib/00/qv_s/                   | grib      |       1 | SINGLE-LEVEL_QV_S                          | icon_global_icosahedral_single-level_{ref_time}_{lead}_QV_S.grib2.bz2                           |
# | icon    | icon/grib/00/rain_con/               | grib      |       1 | SINGLE-LEVEL_RAIN_CON                      | icon_global_icosahedral_single-level_{ref_time}_{lead}_RAIN_CON.grib2.bz2                       |
# | icon    | icon/grib/00/rain_gsp/               | grib      |       1 | SINGLE-LEVEL_RAIN_GSP                      | icon_global_icosahedral_single-level_{ref_time}_{lead}_RAIN_GSP.grib2.bz2                       |
# | icon    | icon/grib/00/relhum/                 | grib      |       1 | ICOSAHEDRAL_PRESSURE-LEVEL_RELHUM          | icon_global_icosahedral_pressure-level_{ref_time}_{lead}_{lead}_RELHUM.grib2.bz2                |
# | icon    | icon/grib/00/relhum_2m/              | grib      |       1 | SINGLE-LEVEL_RELHUM_2M                     | icon_global_icosahedral_single-level_{ref_time}_{lead}_RELHUM_2M.grib2.bz2                      |
# | icon    | icon/grib/00/rho_snow/               | grib      |       1 | SINGLE-LEVEL_RHO_SNOW                      | icon_global_icosahedral_single-level_{ref_time}_{lead}_RHO_SNOW.grib2.bz2                       |
# | icon    | icon/grib/00/rootdp/                 | grib      |       1 | ICOSAHEDRAL_TIME-INVARIANT_ROOTDP          | icon_global_icosahedral_time-invariant_{ref_time}_ROOTDP.grib2.bz2                              |
# | icon    | icon/grib/00/runoff_g/               | grib      |       1 | SINGLE-LEVEL_RUNOFF_G                      | icon_global_icosahedral_single-level_{ref_time}_{lead}_RUNOFF_G.grib2.bz2                       |
# | icon    | icon/grib/00/runoff_s/               | grib      |       1 | SINGLE-LEVEL_RUNOFF_S                      | icon_global_icosahedral_single-level_{ref_time}_{lead}_RUNOFF_S.grib2.bz2                       |
# | icon    | icon/grib/00/snoag/                  | grib      |       1 | ICOSAHEDRAL_TIME-INVARIANT_SNOAG           | icon_global_icosahedral_time-invariant_{ref_time}_SNOAG.grib2.bz2                               |
# | icon    | icon/grib/00/snow_con/               | grib      |       1 | SINGLE-LEVEL_SNOW_CON                      | icon_global_icosahedral_single-level_{ref_time}_{lead}_SNOW_CON.grib2.bz2                       |
# | icon    | icon/grib/00/snow_gsp/               | grib      |       1 | SINGLE-LEVEL_SNOW_GSP                      | icon_global_icosahedral_single-level_{ref_time}_{lead}_SNOW_GSP.grib2.bz2                       |
# | icon    | icon/grib/00/soiltyp/                | grib      |       1 | ICOSAHEDRAL_TIME-INVARIANT_SOILTYP         | icon_global_icosahedral_time-invariant_{ref_time}_SOILTYP.grib2.bz2                             |
# | icon    | icon/grib/00/t/                      | grib      |       1 | ICOSAHEDRAL_MODEL-LEVEL_T                  | icon_global_icosahedral_model-level_{ref_time}_{lead}_{lead}_T.grib2.bz2                        |
# | icon    | icon/grib/00/t_2m/                   | grib      |       1 | SINGLE-LEVEL_T_2M                          | icon_global_icosahedral_single-level_{ref_time}_{lead}_T_2M.grib2.bz2                           |
# | icon    | icon/grib/00/t_bot_lk/               | grib      |       1 | T_BOT_LK                                   | icon_global_icosahedral_single-level_{ref_time}_{lead}_T_BOT_LK.grib2.bz2                       |
# | icon    | icon/grib/00/t_g/                    | grib      |       1 | SINGLE-LEVEL_T_G                           | icon_global_icosahedral_single-level_{ref_time}_{lead}_T_G.grib2.bz2                            |
# | icon    | icon/grib/00/t_ice/                  | grib      |       1 | SINGLE-LEVEL_T_ICE                         | icon_global_icosahedral_single-level_{ref_time}_{lead}_T_ICE.grib2.bz2                          |
# | icon    | icon/grib/00/t_mnw_lk/               | grib      |       1 | T_MNW_LK                                   | icon_global_icosahedral_single-level_{ref_time}_{lead}_T_MNW_LK.grib2.bz2                       |
# | icon    | icon/grib/00/t_snow/                 | grib      |       1 | SINGLE-LEVEL_T_SNOW                        | icon_global_icosahedral_single-level_{ref_time}_{lead}_T_SNOW.grib2.bz2                         |
# | icon    | icon/grib/00/t_so/                   | grib      |       2 | SOIL-LEVEL_T_SO, T_SO                      | icon_global_icosahedral_soil-level_{ref_time}_{lead}_0_T_SO.grib2.bz2                           |
# | icon    | icon/grib/00/t_wml_lk/               | grib      |       1 | T_WML_LK                                   | icon_global_icosahedral_single-level_{ref_time}_{lead}_T_WML_LK.grib2.bz2                       |
# | icon    | icon/grib/00/tch/                    | grib      |       1 | ICOSAHEDRAL_SINGLE-LEVEL_TCH               | icon_global_icosahedral_single-level_{ref_time}_{lead}_TCH.grib2.bz2                            |
# | icon    | icon/grib/00/tcm/                    | grib      |       1 | ICOSAHEDRAL_SINGLE-LEVEL_TCM               | icon_global_icosahedral_single-level_{ref_time}_{lead}_TCM.grib2.bz2                            |
# | icon    | icon/grib/00/td_2m/                  | grib      |       1 | SINGLE-LEVEL_TD_2M                         | icon_global_icosahedral_single-level_{ref_time}_{lead}_TD_2M.grib2.bz2                          |
# | icon    | icon/grib/00/tke/                    | grib      |       1 | ICOSAHEDRAL_MODEL-LEVEL_TKE                | icon_global_icosahedral_model-level_{ref_time}_{lead}_{lead}_TKE.grib2.bz2                      |
# | icon    | icon/grib/00/tmax_2m/                | grib      |       1 | SINGLE-LEVEL_TMAX_2M                       | icon_global_icosahedral_single-level_{ref_time}_{lead}_TMAX_2M.grib2.bz2                        |
# | icon    | icon/grib/00/tmin_2m/                | grib      |       1 | SINGLE-LEVEL_TMIN_2M                       | icon_global_icosahedral_single-level_{ref_time}_{lead}_TMIN_2M.grib2.bz2                        |
# | icon    | icon/grib/00/tot_prec/               | grib      |       1 | SINGLE-LEVEL_TOT_PREC                      | icon_global_icosahedral_single-level_{ref_time}_{lead}_TOT_PREC.grib2.bz2                       |
# | icon    | icon/grib/00/tqc/                    | grib      |       1 | ICOSAHEDRAL_SINGLE-LEVEL_TQC               | icon_global_icosahedral_single-level_{ref_time}_{lead}_TQC.grib2.bz2                            |
# | icon    | icon/grib/00/tqc_dia/                | grib      |       1 | SINGLE-LEVEL_TQC_DIA                       | icon_global_icosahedral_single-level_{ref_time}_{lead}_TQC_DIA.grib2.bz2                        |
# | icon    | icon/grib/00/tqi/                    | grib      |       1 | ICOSAHEDRAL_SINGLE-LEVEL_TQI               | icon_global_icosahedral_single-level_{ref_time}_{lead}_TQI.grib2.bz2                            |
# | icon    | icon/grib/00/tqi_dia/                | grib      |       1 | SINGLE-LEVEL_TQI_DIA                       | icon_global_icosahedral_single-level_{ref_time}_{lead}_TQI_DIA.grib2.bz2                        |
# | icon    | icon/grib/00/tqr/                    | grib      |       1 | ICOSAHEDRAL_SINGLE-LEVEL_TQR               | icon_global_icosahedral_single-level_{ref_time}_{lead}_TQR.grib2.bz2                            |
# | icon    | icon/grib/00/tqs/                    | grib      |       1 | ICOSAHEDRAL_SINGLE-LEVEL_TQS               | icon_global_icosahedral_single-level_{ref_time}_{lead}_TQS.grib2.bz2                            |
# | icon    | icon/grib/00/tqv/                    | grib      |       1 | ICOSAHEDRAL_SINGLE-LEVEL_TQV               | icon_global_icosahedral_single-level_{ref_time}_{lead}_TQV.grib2.bz2                            |
# | icon    | icon/grib/00/u/                      | grib      |       1 | ICOSAHEDRAL_MODEL-LEVEL_U                  | icon_global_icosahedral_model-level_{ref_time}_{lead}_{lead}_U.grib2.bz2                        |
# | icon    | icon/grib/00/u_10m/                  | grib      |       1 | SINGLE-LEVEL_U_10M                         | icon_global_icosahedral_single-level_{ref_time}_{lead}_U_{lead}M.grib2.bz2                      |
# | icon    | icon/grib/00/v/                      | grib      |       1 | ICOSAHEDRAL_MODEL-LEVEL_V                  | icon_global_icosahedral_model-level_{ref_time}_{lead}_{lead}_V.grib2.bz2                        |
# | icon    | icon/grib/00/v_10m/                  | grib      |       1 | SINGLE-LEVEL_V_10M                         | icon_global_icosahedral_single-level_{ref_time}_{lead}_V_{lead}M.grib2.bz2                      |
# | icon    | icon/grib/00/vmax_10m/               | grib      |       1 | SINGLE-LEVEL_VMAX_10M                      | icon_global_icosahedral_single-level_{ref_time}_{lead}_VMAX_{lead}M.grib2.bz2                   |
# | icon    | icon/grib/00/w/                      | grib      |       1 | ICOSAHEDRAL_MODEL-LEVEL_W                  | icon_global_icosahedral_model-level_{ref_time}_{lead}_{lead}_W.grib2.bz2                        |
# | icon    | icon/grib/00/w_i/                    | grib      |       1 | SINGLE-LEVEL_W_I                           | icon_global_icosahedral_single-level_{ref_time}_{lead}_W_I.grib2.bz2                            |
# | icon    | icon/grib/00/w_snow/                 | grib      |       1 | SINGLE-LEVEL_W_SNOW                        | icon_global_icosahedral_single-level_{ref_time}_{lead}_W_SNOW.grib2.bz2                         |
# | icon    | icon/grib/00/w_so/                   | grib      |       2 | SOIL-LEVEL_W_SO, W_SO                      | icon_global_icosahedral_soil-level_{ref_time}_{lead}_0_W_SO.grib2.bz2                           |
# | icon    | icon/grib/00/w_so_ice/               | grib      |       1 | W_SO_ICE                                   | icon_global_icosahedral_soil-level_{ref_time}_{lead}_0_W_SO_ICE.grib2.bz2                       |
# | icon    | icon/grib/00/ww/                     | grib      |       1 | ICOSAHEDRAL_SINGLE-LEVEL_WW                | icon_global_icosahedral_single-level_{ref_time}_{lead}_WW.grib2.bz2                             |
# | icon    | icon/grib/00/z0/                     | grib      |       1 | ICOSAHEDRAL_SINGLE-LEVEL_Z0                | icon_global_icosahedral_single-level_{ref_time}_{lead}_Z0.grib2.bz2                             |
# | icon    | icon/grib/06/alb_rad/                | grib      |       1 | SINGLE-LEVEL_ALB_RAD                       | icon_global_icosahedral_single-level_{ref_time}_{lead}_ALB_RAD.grib2.bz2                        |
# | icon    | icon/grib/06/alb_seaice/             | grib      |       1 | TIME-INVARIANT_ALB_SEAICE                  | icon_global_icosahedral_time-invariant_{ref_time}_ALB_SEAICE.grib2.bz2                          |
# | icon    | icon/grib/06/alhfl_s/                | grib      |       1 | SINGLE-LEVEL_ALHFL_S                       | icon_global_icosahedral_single-level_{ref_time}_{lead}_ALHFL_S.grib2.bz2                        |
# | icon    | icon/grib/06/ashfl_s/                | grib      |       1 | SINGLE-LEVEL_ASHFL_S                       | icon_global_icosahedral_single-level_{ref_time}_{lead}_ASHFL_S.grib2.bz2                        |
# | icon    | icon/grib/06/asob_s/                 | grib      |       1 | SINGLE-LEVEL_ASOB_S                        | icon_global_icosahedral_single-level_{ref_time}_{lead}_ASOB_S.grib2.bz2                         |
# | icon    | icon/grib/06/asob_s_cs/              | grib      |       1 | ASOB_S_CS                                  | icon_global_icosahedral_single-level_{ref_time}_{lead}_ASOB_S_CS.grib2.bz2                      |
# | icon    | icon/grib/06/asob_t/                 | grib      |       1 | SINGLE-LEVEL_ASOB_T                        | icon_global_icosahedral_single-level_{ref_time}_{lead}_ASOB_T.grib2.bz2                         |
# | icon    | icon/grib/06/aswdifd_s/              | grib      |       1 | SINGLE-LEVEL_ASWDIFD_S                     | icon_global_icosahedral_single-level_{ref_time}_{lead}_ASWDIFD_S.grib2.bz2                      |
# | icon    | icon/grib/06/aswdifu_s/              | grib      |       1 | SINGLE-LEVEL_ASWDIFU_S                     | icon_global_icosahedral_single-level_{ref_time}_{lead}_ASWDIFU_S.grib2.bz2                      |
# | icon    | icon/grib/06/aswdir_s/               | grib      |       1 | SINGLE-LEVEL_ASWDIR_S                      | icon_global_icosahedral_single-level_{ref_time}_{lead}_ASWDIR_S.grib2.bz2                       |
# | icon    | icon/grib/06/athb_s/                 | grib      |       1 | SINGLE-LEVEL_ATHB_S                        | icon_global_icosahedral_single-level_{ref_time}_{lead}_ATHB_S.grib2.bz2                         |
# | icon    | icon/grib/06/athb_t/                 | grib      |       1 | SINGLE-LEVEL_ATHB_T                        | icon_global_icosahedral_single-level_{ref_time}_{lead}_ATHB_T.grib2.bz2                         |
# | icon    | icon/grib/06/aumfl_s/                | grib      |       1 | SINGLE-LEVEL_AUMFL_S                       | icon_global_icosahedral_single-level_{ref_time}_{lead}_AUMFL_S.grib2.bz2                        |
# | icon    | icon/grib/06/avmfl_s/                | grib      |       1 | SINGLE-LEVEL_AVMFL_S                       | icon_global_icosahedral_single-level_{ref_time}_{lead}_AVMFL_S.grib2.bz2                        |
# | icon    | icon/grib/06/c_t_lk/                 | grib      |       1 | C_T_LK                                     | icon_global_icosahedral_single-level_{ref_time}_{lead}_C_T_LK.grib2.bz2                         |
# | icon    | icon/grib/06/cape_con/               | grib      |       1 | SINGLE-LEVEL_CAPE_CON                      | icon_global_icosahedral_single-level_{ref_time}_{lead}_CAPE_CON.grib2.bz2                       |
# | icon    | icon/grib/06/cape_ml/                | grib      |       1 | SINGLE-LEVEL_CAPE_ML                       | icon_global_icosahedral_single-level_{ref_time}_{lead}_CAPE_ML.grib2.bz2                        |
# | icon    | icon/grib/06/clat/                   | grib      |       1 | ICOSAHEDRAL_TIME-INVARIANT_CLAT            | icon_global_icosahedral_time-invariant_{ref_time}_CLAT.grib2.bz2                                |
# | icon    | icon/grib/06/clc/                    | grib      |       1 | ICOSAHEDRAL_MODEL-LEVEL_CLC                | icon_global_icosahedral_model-level_{ref_time}_{lead}_{lead}_CLC.grib2.bz2                      |
# | icon    | icon/grib/06/clch/                   | grib      |       1 | ICOSAHEDRAL_SINGLE-LEVEL_CLCH              | icon_global_icosahedral_single-level_{ref_time}_{lead}_CLCH.grib2.bz2                           |
# | icon    | icon/grib/06/clcl/                   | grib      |       1 | ICOSAHEDRAL_SINGLE-LEVEL_CLCL              | icon_global_icosahedral_single-level_{ref_time}_{lead}_CLCL.grib2.bz2                           |
# | icon    | icon/grib/06/clcm/                   | grib      |       1 | ICOSAHEDRAL_SINGLE-LEVEL_CLCM              | icon_global_icosahedral_single-level_{ref_time}_{lead}_CLCM.grib2.bz2                           |
# | icon    | icon/grib/06/clct/                   | grib      |       1 | ICOSAHEDRAL_SINGLE-LEVEL_CLCT              | icon_global_icosahedral_single-level_{ref_time}_{lead}_CLCT.grib2.bz2                           |
# | icon    | icon/grib/06/clct_mod/               | grib      |       1 | SINGLE-LEVEL_CLCT_MOD                      | icon_global_icosahedral_single-level_{ref_time}_{lead}_CLCT_MOD.grib2.bz2                       |
# | icon    | icon/grib/06/cldepth/                | grib      |       1 | ICOSAHEDRAL_SINGLE-LEVEL_CLDEPTH           | icon_global_icosahedral_single-level_{ref_time}_{lead}_CLDEPTH.grib2.bz2                        |
# | icon    | icon/grib/06/clon/                   | grib      |       1 | ICOSAHEDRAL_TIME-INVARIANT_CLON            | icon_global_icosahedral_time-invariant_{ref_time}_CLON.grib2.bz2                                |
# | icon    | icon/grib/06/depth_lk/               | grib      |       1 | TIME-INVARIANT_DEPTH_LK                    | icon_global_icosahedral_time-invariant_{ref_time}_DEPTH_LK.grib2.bz2                            |
# | icon    | icon/grib/06/elat/                   | grib      |       1 | ICOSAHEDRAL_TIME-INVARIANT_ELAT            | icon_global_icosahedral_time-invariant_{ref_time}_ELAT.grib2.bz2                                |
# | icon    | icon/grib/06/elon/                   | grib      |       1 | ICOSAHEDRAL_TIME-INVARIANT_ELON            | icon_global_icosahedral_time-invariant_{ref_time}_ELON.grib2.bz2                                |
# | icon    | icon/grib/06/evap_pl/                | grib      |       1 | TIME-INVARIANT_EVAP_PL                     | icon_global_icosahedral_time-invariant_{ref_time}_EVAP_PL.grib2.bz2                             |
# | icon    | icon/grib/06/fi/                     | grib      |       1 | ICOSAHEDRAL_PRESSURE-LEVEL_FI              | icon_global_icosahedral_pressure-level_{ref_time}_{lead}_{lead}_FI.grib2.bz2                    |
# | icon    | icon/grib/06/fr_ice/                 | grib      |       1 | SINGLE-LEVEL_FR_ICE                        | icon_global_icosahedral_single-level_{ref_time}_{lead}_FR_ICE.grib2.bz2                         |
# | icon    | icon/grib/06/fr_lake/                | grib      |       1 | TIME-INVARIANT_FR_LAKE                     | icon_global_icosahedral_time-invariant_{ref_time}_FR_LAKE.grib2.bz2                             |
# | icon    | icon/grib/06/fr_land/                | grib      |       1 | TIME-INVARIANT_FR_LAND                     | icon_global_icosahedral_time-invariant_{ref_time}_FR_LAND.grib2.bz2                             |
# | icon    | icon/grib/06/freshsnw/               | grib      |       1 | ICOSAHEDRAL_SINGLE-LEVEL_FRESHSNW          | icon_global_icosahedral_single-level_{ref_time}_{lead}_FRESHSNW.grib2.bz2                       |
# | icon    | icon/grib/06/h_ice/                  | grib      |       1 | SINGLE-LEVEL_H_ICE                         | icon_global_icosahedral_single-level_{ref_time}_{lead}_H_ICE.grib2.bz2                          |
# | icon    | icon/grib/06/h_ml_lk/                | grib      |       1 | H_ML_LK                                    | icon_global_icosahedral_single-level_{ref_time}_{lead}_H_ML_LK.grib2.bz2                        |
# | icon    | icon/grib/06/h_snow/                 | grib      |       1 | SINGLE-LEVEL_H_SNOW                        | icon_global_icosahedral_single-level_{ref_time}_{lead}_H_SNOW.grib2.bz2                         |
# | icon    | icon/grib/06/hbas_con/               | grib      |       1 | SINGLE-LEVEL_HBAS_CON                      | icon_global_icosahedral_single-level_{ref_time}_{lead}_HBAS_CON.grib2.bz2                       |
# | icon    | icon/grib/06/hhl/                    | grib      |       1 | ICOSAHEDRAL_TIME-INVARIANT_HHL             | icon_global_icosahedral_time-invariant_{ref_time}_{lead}_HHL.grib2.bz2                          |
# | icon    | icon/grib/06/hsnow_max/              | grib      |       1 | TIME-INVARIANT_HSNOW_MAX                   | icon_global_icosahedral_time-invariant_{ref_time}_HSNOW_MAX.grib2.bz2                           |
# | icon    | icon/grib/06/hsurf/                  | grib      |       1 | ICOSAHEDRAL_TIME-INVARIANT_HSURF           | icon_global_icosahedral_time-invariant_{ref_time}_HSURF.grib2.bz2                               |
# | icon    | icon/grib/06/htop_con/               | grib      |       1 | SINGLE-LEVEL_HTOP_CON                      | icon_global_icosahedral_single-level_{ref_time}_{lead}_HTOP_CON.grib2.bz2                       |
# | icon    | icon/grib/06/htop_dc/                | grib      |       1 | SINGLE-LEVEL_HTOP_DC                       | icon_global_icosahedral_single-level_{ref_time}_{lead}_HTOP_DC.grib2.bz2                        |
# | icon    | icon/grib/06/hzerocl/                | grib      |       1 | ICOSAHEDRAL_SINGLE-LEVEL_HZEROCL           | icon_global_icosahedral_single-level_{ref_time}_{lead}_HZEROCL.grib2.bz2                        |
# | icon    | icon/grib/06/lai/                    | grib      |       1 | ICOSAHEDRAL_TIME-INVARIANT_LAI             | icon_global_icosahedral_time-invariant_{ref_time}_LAI.grib2.bz2                                 |
# | icon    | icon/grib/06/ndviratio/              | grib      |       1 | ICOSAHEDRAL_TIME-INVARIANT_NDVIRATIO       | icon_global_icosahedral_time-invariant_{ref_time}_NDVIRATIO.grib2.bz2                           |
# | icon    | icon/grib/06/p/                      | grib      |       1 | ICOSAHEDRAL_MODEL-LEVEL_P                  | icon_global_icosahedral_model-level_{ref_time}_{lead}_{lead}_P.grib2.bz2                        |
# | icon    | icon/grib/06/plcov/                  | grib      |       1 | ICOSAHEDRAL_TIME-INVARIANT_PLCOV           | icon_global_icosahedral_time-invariant_{ref_time}_PLCOV.grib2.bz2                               |
# | icon    | icon/grib/06/pmsl/                   | grib      |       1 | ICOSAHEDRAL_SINGLE-LEVEL_PMSL              | icon_global_icosahedral_single-level_{ref_time}_{lead}_PMSL.grib2.bz2                           |
# | icon    | icon/grib/06/ps/                     | grib      |       1 | ICOSAHEDRAL_SINGLE-LEVEL_PS                | icon_global_icosahedral_single-level_{ref_time}_{lead}_PS.grib2.bz2                             |
# | icon    | icon/grib/06/qc/                     | grib      |       1 | ICOSAHEDRAL_MODEL-LEVEL_QC                 | icon_global_icosahedral_model-level_{ref_time}_{lead}_{lead}_QC.grib2.bz2                       |
# | icon    | icon/grib/06/qi/                     | grib      |       1 | ICOSAHEDRAL_MODEL-LEVEL_QI                 | icon_global_icosahedral_model-level_{ref_time}_{lead}_{lead}_QI.grib2.bz2                       |
# | icon    | icon/grib/06/qv/                     | grib      |       1 | ICOSAHEDRAL_MODEL-LEVEL_QV                 | icon_global_icosahedral_model-level_{ref_time}_{lead}_{lead}_QV.grib2.bz2                       |
# | icon    | icon/grib/06/qv_s/                   | grib      |       1 | SINGLE-LEVEL_QV_S                          | icon_global_icosahedral_single-level_{ref_time}_{lead}_QV_S.grib2.bz2                           |
# | icon    | icon/grib/06/rain_con/               | grib      |       1 | SINGLE-LEVEL_RAIN_CON                      | icon_global_icosahedral_single-level_{ref_time}_{lead}_RAIN_CON.grib2.bz2                       |
# | icon    | icon/grib/06/rain_gsp/               | grib      |       1 | SINGLE-LEVEL_RAIN_GSP                      | icon_global_icosahedral_single-level_{ref_time}_{lead}_RAIN_GSP.grib2.bz2                       |
# | icon    | icon/grib/06/relhum/                 | grib      |       1 | ICOSAHEDRAL_PRESSURE-LEVEL_RELHUM          | icon_global_icosahedral_pressure-level_{ref_time}_{lead}_{lead}_RELHUM.grib2.bz2                |
# | icon    | icon/grib/06/relhum_2m/              | grib      |       1 | SINGLE-LEVEL_RELHUM_2M                     | icon_global_icosahedral_single-level_{ref_time}_{lead}_RELHUM_2M.grib2.bz2                      |
# | icon    | icon/grib/06/rho_snow/               | grib      |       1 | SINGLE-LEVEL_RHO_SNOW                      | icon_global_icosahedral_single-level_{ref_time}_{lead}_RHO_SNOW.grib2.bz2                       |
# | icon    | icon/grib/06/rootdp/                 | grib      |       1 | ICOSAHEDRAL_TIME-INVARIANT_ROOTDP          | icon_global_icosahedral_time-invariant_{ref_time}_ROOTDP.grib2.bz2                              |
# | icon    | icon/grib/06/runoff_g/               | grib      |       1 | SINGLE-LEVEL_RUNOFF_G                      | icon_global_icosahedral_single-level_{ref_time}_{lead}_RUNOFF_G.grib2.bz2                       |
# | icon    | icon/grib/06/runoff_s/               | grib      |       1 | SINGLE-LEVEL_RUNOFF_S                      | icon_global_icosahedral_single-level_{ref_time}_{lead}_RUNOFF_S.grib2.bz2                       |
# | icon    | icon/grib/06/snoag/                  | grib      |       1 | ICOSAHEDRAL_TIME-INVARIANT_SNOAG           | icon_global_icosahedral_time-invariant_{ref_time}_SNOAG.grib2.bz2                               |
# | icon    | icon/grib/06/snow_con/               | grib      |       1 | SINGLE-LEVEL_SNOW_CON                      | icon_global_icosahedral_single-level_{ref_time}_{lead}_SNOW_CON.grib2.bz2                       |
# | icon    | icon/grib/06/snow_gsp/               | grib      |       1 | SINGLE-LEVEL_SNOW_GSP                      | icon_global_icosahedral_single-level_{ref_time}_{lead}_SNOW_GSP.grib2.bz2                       |
# | icon    | icon/grib/06/soiltyp/                | grib      |       1 | ICOSAHEDRAL_TIME-INVARIANT_SOILTYP         | icon_global_icosahedral_time-invariant_{ref_time}_SOILTYP.grib2.bz2                             |
# | icon    | icon/grib/06/t/                      | grib      |       1 | ICOSAHEDRAL_MODEL-LEVEL_T                  | icon_global_icosahedral_model-level_{ref_time}_{lead}_{lead}_T.grib2.bz2                        |
# | icon    | icon/grib/06/t_2m/                   | grib      |       1 | SINGLE-LEVEL_T_2M                          | icon_global_icosahedral_single-level_{ref_time}_{lead}_T_2M.grib2.bz2                           |
# | icon    | icon/grib/06/t_bot_lk/               | grib      |       1 | T_BOT_LK                                   | icon_global_icosahedral_single-level_{ref_time}_{lead}_T_BOT_LK.grib2.bz2                       |
# | icon    | icon/grib/06/t_g/                    | grib      |       1 | SINGLE-LEVEL_T_G                           | icon_global_icosahedral_single-level_{ref_time}_{lead}_T_G.grib2.bz2                            |
# | icon    | icon/grib/06/t_ice/                  | grib      |       1 | SINGLE-LEVEL_T_ICE                         | icon_global_icosahedral_single-level_{ref_time}_{lead}_T_ICE.grib2.bz2                          |
# | icon    | icon/grib/06/t_mnw_lk/               | grib      |       1 | T_MNW_LK                                   | icon_global_icosahedral_single-level_{ref_time}_{lead}_T_MNW_LK.grib2.bz2                       |
# | icon    | icon/grib/06/t_snow/                 | grib      |       1 | SINGLE-LEVEL_T_SNOW                        | icon_global_icosahedral_single-level_{ref_time}_{lead}_T_SNOW.grib2.bz2                         |
# | icon    | icon/grib/06/t_so/                   | grib      |       2 | SOIL-LEVEL_T_SO, T_SO                      | icon_global_icosahedral_soil-level_{ref_time}_{lead}_0_T_SO.grib2.bz2                           |
# | icon    | icon/grib/06/t_wml_lk/               | grib      |       1 | T_WML_LK                                   | icon_global_icosahedral_single-level_{ref_time}_{lead}_T_WML_LK.grib2.bz2                       |
# | icon    | icon/grib/06/tch/                    | grib      |       1 | ICOSAHEDRAL_SINGLE-LEVEL_TCH               | icon_global_icosahedral_single-level_{ref_time}_{lead}_TCH.grib2.bz2                            |
# | icon    | icon/grib/06/tcm/                    | grib      |       1 | ICOSAHEDRAL_SINGLE-LEVEL_TCM               | icon_global_icosahedral_single-level_{ref_time}_{lead}_TCM.grib2.bz2                            |
# | icon    | icon/grib/06/td_2m/                  | grib      |       1 | SINGLE-LEVEL_TD_2M                         | icon_global_icosahedral_single-level_{ref_time}_{lead}_TD_2M.grib2.bz2                          |
# | icon    | icon/grib/06/tke/                    | grib      |       1 | ICOSAHEDRAL_MODEL-LEVEL_TKE                | icon_global_icosahedral_model-level_{ref_time}_{lead}_{lead}_TKE.grib2.bz2                      |
# | icon    | icon/grib/06/tmax_2m/                | grib      |       1 | SINGLE-LEVEL_TMAX_2M                       | icon_global_icosahedral_single-level_{ref_time}_{lead}_TMAX_2M.grib2.bz2                        |
# | icon    | icon/grib/06/tmin_2m/                | grib      |       1 | SINGLE-LEVEL_TMIN_2M                       | icon_global_icosahedral_single-level_{ref_time}_{lead}_TMIN_2M.grib2.bz2                        |
# | icon    | icon/grib/06/tot_prec/               | grib      |       1 | SINGLE-LEVEL_TOT_PREC                      | icon_global_icosahedral_single-level_{ref_time}_{lead}_TOT_PREC.grib2.bz2                       |
# | icon    | icon/grib/06/tqc/                    | grib      |       1 | ICOSAHEDRAL_SINGLE-LEVEL_TQC               | icon_global_icosahedral_single-level_{ref_time}_{lead}_TQC.grib2.bz2                            |
# | icon    | icon/grib/06/tqc_dia/                | grib      |       1 | SINGLE-LEVEL_TQC_DIA                       | icon_global_icosahedral_single-level_{ref_time}_{lead}_TQC_DIA.grib2.bz2                        |
# | icon    | icon/grib/06/tqi/                    | grib      |       1 | ICOSAHEDRAL_SINGLE-LEVEL_TQI               | icon_global_icosahedral_single-level_{ref_time}_{lead}_TQI.grib2.bz2                            |
# | icon    | icon/grib/06/tqi_dia/                | grib      |       1 | SINGLE-LEVEL_TQI_DIA                       | icon_global_icosahedral_single-level_{ref_time}_{lead}_TQI_DIA.grib2.bz2                        |
# | icon    | icon/grib/06/tqr/                    | grib      |       1 | ICOSAHEDRAL_SINGLE-LEVEL_TQR               | icon_global_icosahedral_single-level_{ref_time}_{lead}_TQR.grib2.bz2                            |
# | icon    | icon/grib/06/tqs/                    | grib      |       1 | ICOSAHEDRAL_SINGLE-LEVEL_TQS               | icon_global_icosahedral_single-level_{ref_time}_{lead}_TQS.grib2.bz2                            |
# | icon    | icon/grib/06/tqv/                    | grib      |       1 | ICOSAHEDRAL_SINGLE-LEVEL_TQV               | icon_global_icosahedral_single-level_{ref_time}_{lead}_TQV.grib2.bz2                            |
# | icon    | icon/grib/06/u/                      | grib      |       1 | ICOSAHEDRAL_MODEL-LEVEL_U                  | icon_global_icosahedral_model-level_{ref_time}_{lead}_{lead}_U.grib2.bz2                        |
# | icon    | icon/grib/06/u_10m/                  | grib      |       1 | SINGLE-LEVEL_U_10M                         | icon_global_icosahedral_single-level_{ref_time}_{lead}_U_{lead}M.grib2.bz2                      |
# | icon    | icon/grib/06/v/                      | grib      |       1 | ICOSAHEDRAL_MODEL-LEVEL_V                  | icon_global_icosahedral_model-level_{ref_time}_{lead}_{lead}_V.grib2.bz2                        |
# | icon    | icon/grib/06/v_10m/                  | grib      |       1 | SINGLE-LEVEL_V_10M                         | icon_global_icosahedral_single-level_{ref_time}_{lead}_V_{lead}M.grib2.bz2                      |
# | icon    | icon/grib/06/vmax_10m/               | grib      |       1 | SINGLE-LEVEL_VMAX_10M                      | icon_global_icosahedral_single-level_{ref_time}_{lead}_VMAX_{lead}M.grib2.bz2                   |
# | icon    | icon/grib/06/w/                      | grib      |       1 | ICOSAHEDRAL_MODEL-LEVEL_W                  | icon_global_icosahedral_model-level_{ref_time}_{lead}_{lead}_W.grib2.bz2                        |
# | icon    | icon/grib/06/w_i/                    | grib      |       1 | SINGLE-LEVEL_W_I                           | icon_global_icosahedral_single-level_{ref_time}_{lead}_W_I.grib2.bz2                            |
# | icon    | icon/grib/06/w_snow/                 | grib      |       1 | SINGLE-LEVEL_W_SNOW                        | icon_global_icosahedral_single-level_{ref_time}_{lead}_W_SNOW.grib2.bz2                         |
# | icon    | icon/grib/06/w_so/                   | grib      |       2 | SOIL-LEVEL_W_SO, W_SO                      | icon_global_icosahedral_soil-level_{ref_time}_{lead}_0_W_SO.grib2.bz2                           |
# | icon    | icon/grib/06/w_so_ice/               | grib      |       1 | W_SO_ICE                                   | icon_global_icosahedral_soil-level_{ref_time}_{lead}_0_W_SO_ICE.grib2.bz2                       |
# | icon    | icon/grib/06/ww/                     | grib      |       1 | ICOSAHEDRAL_SINGLE-LEVEL_WW                | icon_global_icosahedral_single-level_{ref_time}_{lead}_WW.grib2.bz2                             |
# | icon    | icon/grib/06/z0/                     | grib      |       1 | ICOSAHEDRAL_SINGLE-LEVEL_Z0                | icon_global_icosahedral_single-level_{ref_time}_{lead}_Z0.grib2.bz2                             |
# | icon    | icon/grib/12/alb_rad/                | grib      |       1 | SINGLE-LEVEL_ALB_RAD                       | icon_global_icosahedral_single-level_{ref_time}_{lead}_ALB_RAD.grib2.bz2                        |
# | icon    | icon/grib/12/alb_seaice/             | grib      |       1 | TIME-INVARIANT_ALB_SEAICE                  | icon_global_icosahedral_time-invariant_{ref_time}_ALB_SEAICE.grib2.bz2                          |
# | icon    | icon/grib/12/alhfl_s/                | grib      |       1 | SINGLE-LEVEL_ALHFL_S                       | icon_global_icosahedral_single-level_{ref_time}_{lead}_ALHFL_S.grib2.bz2                        |
# | icon    | icon/grib/12/ashfl_s/                | grib      |       1 | SINGLE-LEVEL_ASHFL_S                       | icon_global_icosahedral_single-level_{ref_time}_{lead}_ASHFL_S.grib2.bz2                        |
# | icon    | icon/grib/12/asob_s/                 | grib      |       1 | SINGLE-LEVEL_ASOB_S                        | icon_global_icosahedral_single-level_{ref_time}_{lead}_ASOB_S.grib2.bz2                         |
# | icon    | icon/grib/12/asob_s_cs/              | grib      |       1 | ASOB_S_CS                                  | icon_global_icosahedral_single-level_{ref_time}_{lead}_ASOB_S_CS.grib2.bz2                      |
# | icon    | icon/grib/12/asob_t/                 | grib      |       1 | SINGLE-LEVEL_ASOB_T                        | icon_global_icosahedral_single-level_{ref_time}_{lead}_ASOB_T.grib2.bz2                         |
# | icon    | icon/grib/12/aswdifd_s/              | grib      |       1 | SINGLE-LEVEL_ASWDIFD_S                     | icon_global_icosahedral_single-level_{ref_time}_{lead}_ASWDIFD_S.grib2.bz2                      |
# | icon    | icon/grib/12/aswdifu_s/              | grib      |       1 | SINGLE-LEVEL_ASWDIFU_S                     | icon_global_icosahedral_single-level_{ref_time}_{lead}_ASWDIFU_S.grib2.bz2                      |
# | icon    | icon/grib/12/aswdir_s/               | grib      |       1 | SINGLE-LEVEL_ASWDIR_S                      | icon_global_icosahedral_single-level_{ref_time}_{lead}_ASWDIR_S.grib2.bz2                       |
# | icon    | icon/grib/12/athb_s/                 | grib      |       1 | SINGLE-LEVEL_ATHB_S                        | icon_global_icosahedral_single-level_{ref_time}_{lead}_ATHB_S.grib2.bz2                         |
# | icon    | icon/grib/12/athb_t/                 | grib      |       1 | SINGLE-LEVEL_ATHB_T                        | icon_global_icosahedral_single-level_{ref_time}_{lead}_ATHB_T.grib2.bz2                         |
# | icon    | icon/grib/12/aumfl_s/                | grib      |       1 | SINGLE-LEVEL_AUMFL_S                       | icon_global_icosahedral_single-level_{ref_time}_{lead}_AUMFL_S.grib2.bz2                        |
# | icon    | icon/grib/12/avmfl_s/                | grib      |       1 | SINGLE-LEVEL_AVMFL_S                       | icon_global_icosahedral_single-level_{ref_time}_{lead}_AVMFL_S.grib2.bz2                        |
# | icon    | icon/grib/12/c_t_lk/                 | grib      |       1 | C_T_LK                                     | icon_global_icosahedral_single-level_{ref_time}_{lead}_C_T_LK.grib2.bz2                         |
# | icon    | icon/grib/12/cape_con/               | grib      |       1 | SINGLE-LEVEL_CAPE_CON                      | icon_global_icosahedral_single-level_{ref_time}_{lead}_CAPE_CON.grib2.bz2                       |
# ...
# | icon-eu | icon-eu/grib/21/clct/                | grib      |       1 | REGULAR-LAT-LON_SINGLE-LEVEL_CLCT          | icon-eu_europe_regular-lat-lon_single-level_{ref_time}_{lead}_CLCT.grib2.bz2                    |
# | icon-eu | icon-eu/grib/21/clct_mod/            | grib      |       1 | SINGLE-LEVEL_CLCT_MOD                      | icon-eu_europe_regular-lat-lon_single-level_{ref_time}_{lead}_CLCT_MOD.grib2.bz2                |
# | icon-eu | icon-eu/grib/21/cldepth/             | grib      |       1 | REGULAR-LAT-LON_SINGLE-LEVEL_CLDEPTH       | icon-eu_europe_regular-lat-lon_single-level_{ref_time}_{lead}_CLDEPTH.grib2.bz2                 |
# | icon-eu | icon-eu/grib/21/depth_lk/            | grib      |       1 | TIME-INVARIANT_DEPTH_LK                    | icon-eu_europe_regular-lat-lon_time-invariant_{ref_time}_DEPTH_LK.grib2.bz2                     |
# | icon-eu | icon-eu/grib/21/fi/                  | grib      |       1 | REGULAR-LAT-LON_PRESSURE-LEVEL_FI          | icon-eu_europe_regular-lat-lon_pressure-level_{ref_time}_{lead}_{lead}_FI.grib2.bz2             |
# | icon-eu | icon-eu/grib/21/fr_lake/             | grib      |       1 | TIME-INVARIANT_FR_LAKE                     | icon-eu_europe_regular-lat-lon_time-invariant_{ref_time}_FR_LAKE.grib2.bz2                      |
# | icon-eu | icon-eu/grib/21/fr_land/             | grib      |       1 | TIME-INVARIANT_FR_LAND                     | icon-eu_europe_regular-lat-lon_time-invariant_{ref_time}_FR_LAND.grib2.bz2                      |
# | icon-eu | icon-eu/grib/21/h_ice/               | grib      |       1 | SINGLE-LEVEL_H_ICE                         | icon-eu_europe_regular-lat-lon_single-level_{ref_time}_{lead}_H_ICE.grib2.bz2                   |
# | icon-eu | icon-eu/grib/21/h_snow/              | grib      |       1 | SINGLE-LEVEL_H_SNOW                        | icon-eu_europe_regular-lat-lon_single-level_{ref_time}_{lead}_H_SNOW.grib2.bz2                  |
# | icon-eu | icon-eu/grib/21/hbas_con/            | grib      |       1 | SINGLE-LEVEL_HBAS_CON                      | icon-eu_europe_regular-lat-lon_single-level_{ref_time}_{lead}_HBAS_CON.grib2.bz2                |
# | icon-eu | icon-eu/grib/21/hhl/                 | grib      |       1 | REGULAR-LAT-LON_TIME-INVARIANT_HHL         | icon-eu_europe_regular-lat-lon_time-invariant_{ref_time}_{lead}_HHL.grib2.bz2                   |
# | icon-eu | icon-eu/grib/21/hsurf/               | grib      |       1 | REGULAR-LAT-LON_TIME-INVARIANT_HSURF       | icon-eu_europe_regular-lat-lon_time-invariant_{ref_time}_HSURF.grib2.bz2                        |
# | icon-eu | icon-eu/grib/21/htop_con/            | grib      |       1 | SINGLE-LEVEL_HTOP_CON                      | icon-eu_europe_regular-lat-lon_single-level_{ref_time}_{lead}_HTOP_CON.grib2.bz2                |
# | icon-eu | icon-eu/grib/21/htop_dc/             | grib      |       1 | SINGLE-LEVEL_HTOP_DC                       | icon-eu_europe_regular-lat-lon_single-level_{ref_time}_{lead}_HTOP_DC.grib2.bz2                 |
# | icon-eu | icon-eu/grib/21/hzerocl/             | grib      |       1 | REGULAR-LAT-LON_SINGLE-LEVEL_HZEROCL       | icon-eu_europe_regular-lat-lon_single-level_{ref_time}_{lead}_HZEROCL.grib2.bz2                 |
# | icon-eu | icon-eu/grib/21/lai/                 | grib      |       1 | REGULAR-LAT-LON_TIME-INVARIANT_LAI         | icon-eu_europe_regular-lat-lon_time-invariant_{ref_time}_LAI.grib2.bz2                          |
# | icon-eu | icon-eu/grib/21/lpi_con_max/         | grib      |       1 | LPI_CON_MAX                                | icon-eu_europe_regular-lat-lon_single-level_{ref_time}_{lead}_LPI_CON_MAX.grib2.bz2             |
# | icon-eu | icon-eu/grib/21/mh/                  | grib      |       1 | REGULAR-LAT-LON_SINGLE-LEVEL_MH            | icon-eu_europe_regular-lat-lon_single-level_{ref_time}_{lead}_MH.grib2.bz2                      |
# | icon-eu | icon-eu/grib/21/omega/               | grib      |       1 | REGULAR-LAT-LON_PRESSURE-LEVEL_OMEGA       | icon-eu_europe_regular-lat-lon_pressure-level_{ref_time}_{lead}_{lead}_OMEGA.grib2.bz2          |
# | icon-eu | icon-eu/grib/21/p/                   | grib      |       1 | REGULAR-LAT-LON_MODEL-LEVEL_P              | icon-eu_europe_regular-lat-lon_model-level_{ref_time}_{lead}_{lead}_P.grib2.bz2                 |
# | icon-eu | icon-eu/grib/21/plcov/               | grib      |       1 | REGULAR-LAT-LON_TIME-INVARIANT_PLCOV       | icon-eu_europe_regular-lat-lon_time-invariant_{ref_time}_PLCOV.grib2.bz2                        |
# | icon-eu | icon-eu/grib/21/pmsl/                | grib      |       1 | REGULAR-LAT-LON_SINGLE-LEVEL_PMSL          | icon-eu_europe_regular-lat-lon_single-level_{ref_time}_{lead}_PMSL.grib2.bz2                    |
# | icon-eu | icon-eu/grib/21/ps/                  | grib      |       1 | REGULAR-LAT-LON_SINGLE-LEVEL_PS            | icon-eu_europe_regular-lat-lon_single-level_{ref_time}_{lead}_PS.grib2.bz2                      |
# | icon-eu | icon-eu/grib/21/qc/                  | grib      |       1 | REGULAR-LAT-LON_MODEL-LEVEL_QC             | icon-eu_europe_regular-lat-lon_model-level_{ref_time}_{lead}_{lead}_QC.grib2.bz2                |
# | icon-eu | icon-eu/grib/21/qi/                  | grib      |       1 | REGULAR-LAT-LON_MODEL-LEVEL_QI             | icon-eu_europe_regular-lat-lon_model-level_{ref_time}_{lead}_{lead}_QI.grib2.bz2                |
# | icon-eu | icon-eu/grib/21/qv/                  | grib      |       1 | REGULAR-LAT-LON_MODEL-LEVEL_QV             | icon-eu_europe_regular-lat-lon_model-level_{ref_time}_{lead}_{lead}_QV.grib2.bz2                |
# | icon-eu | icon-eu/grib/21/qv_2m/               | grib      |       1 | SINGLE-LEVEL_QV_2M                         | icon-eu_europe_regular-lat-lon_single-level_{ref_time}_{lead}_QV_2M.grib2.bz2                   |
# | icon-eu | icon-eu/grib/21/qv_s/                | grib      |       1 | SINGLE-LEVEL_QV_S                          | icon-eu_europe_regular-lat-lon_single-level_{ref_time}_{lead}_QV_S.grib2.bz2                    |
# | icon-eu | icon-eu/grib/21/rain_con/            | grib      |       1 | SINGLE-LEVEL_RAIN_CON                      | icon-eu_europe_regular-lat-lon_single-level_{ref_time}_{lead}_RAIN_CON.grib2.bz2                |
# | icon-eu | icon-eu/grib/21/rain_gsp/            | grib      |       1 | SINGLE-LEVEL_RAIN_GSP                      | icon-eu_europe_regular-lat-lon_single-level_{ref_time}_{lead}_RAIN_GSP.grib2.bz2                |
# | icon-eu | icon-eu/grib/21/relhum/              | grib      |       1 | REGULAR-LAT-LON_PRESSURE-LEVEL_RELHUM      | icon-eu_europe_regular-lat-lon_pressure-level_{ref_time}_{lead}_{lead}_RELHUM.grib2.bz2         |
# | icon-eu | icon-eu/grib/21/relhum_2m/           | grib      |       1 | SINGLE-LEVEL_RELHUM_2M                     | icon-eu_europe_regular-lat-lon_single-level_{ref_time}_{lead}_RELHUM_2M.grib2.bz2               |
# | icon-eu | icon-eu/grib/21/rho_snow/            | grib      |       1 | SINGLE-LEVEL_RHO_SNOW                      | icon-eu_europe_regular-lat-lon_single-level_{ref_time}_{lead}_RHO_SNOW.grib2.bz2                |
# | icon-eu | icon-eu/grib/21/rlat/                | grib      |       1 | REGULAR-LAT-LON_TIME-INVARIANT_RLAT        | icon-eu_europe_regular-lat-lon_time-invariant_{ref_time}_RLAT.grib2.bz2                         |
# | icon-eu | icon-eu/grib/21/rlon/                | grib      |       1 | REGULAR-LAT-LON_TIME-INVARIANT_RLON        | icon-eu_europe_regular-lat-lon_time-invariant_{ref_time}_RLON.grib2.bz2                         |
# | icon-eu | icon-eu/grib/21/rootdp/              | grib      |       1 | REGULAR-LAT-LON_TIME-INVARIANT_ROOTDP      | icon-eu_europe_regular-lat-lon_time-invariant_{ref_time}_ROOTDP.grib2.bz2                       |
# | icon-eu | icon-eu/grib/21/runoff_g/            | grib      |       1 | SINGLE-LEVEL_RUNOFF_G                      | icon-eu_europe_regular-lat-lon_single-level_{ref_time}_{lead}_RUNOFF_G.grib2.bz2                |
# | icon-eu | icon-eu/grib/21/runoff_s/            | grib      |       1 | SINGLE-LEVEL_RUNOFF_S                      | icon-eu_europe_regular-lat-lon_single-level_{ref_time}_{lead}_RUNOFF_S.grib2.bz2                |
# | icon-eu | icon-eu/grib/21/snow_con/            | grib      |       1 | SINGLE-LEVEL_SNOW_CON                      | icon-eu_europe_regular-lat-lon_single-level_{ref_time}_{lead}_SNOW_CON.grib2.bz2                |
# | icon-eu | icon-eu/grib/21/snow_gsp/            | grib      |       1 | SINGLE-LEVEL_SNOW_GSP                      | icon-eu_europe_regular-lat-lon_single-level_{ref_time}_{lead}_SNOW_GSP.grib2.bz2                |
# | icon-eu | icon-eu/grib/21/snowlmt/             | grib      |       1 | REGULAR-LAT-LON_SINGLE-LEVEL_SNOWLMT       | icon-eu_europe_regular-lat-lon_single-level_{ref_time}_{lead}_SNOWLMT.grib2.bz2                 |
# | icon-eu | icon-eu/grib/21/soiltyp/             | grib      |       1 | REGULAR-LAT-LON_TIME-INVARIANT_SOILTYP     | icon-eu_europe_regular-lat-lon_time-invariant_{ref_time}_SOILTYP.grib2.bz2                      |
# | icon-eu | icon-eu/grib/21/synmsg_bt_cl_ir10.8/ | grib      |       1 | BT_CL_IR10.8                               | icon-eu_europe_regular-lat-lon_single-level_{ref_time}_{lead}_SYNMSG_BT_CL_IR{lead}.8.grib2.bz2 |
# | icon-eu | icon-eu/grib/21/synmsg_bt_cl_wv6.2/  | grib      |       1 | BT_CL_WV6.2                                | icon-eu_europe_regular-lat-lon_single-level_{ref_time}_{lead}_SYNMSG_BT_CL_WV6.2.grib2.bz2      |
# | icon-eu | icon-eu/grib/21/t/                   | grib      |       1 | REGULAR-LAT-LON_MODEL-LEVEL_T              | icon-eu_europe_regular-lat-lon_model-level_{ref_time}_{lead}_{lead}_T.grib2.bz2                 |
# | icon-eu | icon-eu/grib/21/t_2m/                | grib      |       1 | SINGLE-LEVEL_T_2M                          | icon-eu_europe_regular-lat-lon_single-level_{ref_time}_{lead}_T_2M.grib2.bz2                    |
# | icon-eu | icon-eu/grib/21/t_g/                 | grib      |       1 | SINGLE-LEVEL_T_G                           | icon-eu_europe_regular-lat-lon_single-level_{ref_time}_{lead}_T_G.grib2.bz2                     |
# | icon-eu | icon-eu/grib/21/t_ice/               | grib      |       1 | SINGLE-LEVEL_T_ICE                         | icon-eu_europe_regular-lat-lon_single-level_{ref_time}_{lead}_T_ICE.grib2.bz2                   |
# | icon-eu | icon-eu/grib/21/t_snow/              | grib      |       1 | SINGLE-LEVEL_T_SNOW                        | icon-eu_europe_regular-lat-lon_single-level_{ref_time}_{lead}_T_SNOW.grib2.bz2                  |
# | icon-eu | icon-eu/grib/21/t_so/                | grib      |       2 | SOIL-LEVEL_T_SO, T_SO                      | icon-eu_europe_regular-lat-lon_soil-level_{ref_time}_{lead}_0_T_SO.grib2.bz2                    |
# | icon-eu | icon-eu/grib/21/tch/                 | grib      |       1 | REGULAR-LAT-LON_SINGLE-LEVEL_TCH           | icon-eu_europe_regular-lat-lon_single-level_{ref_time}_{lead}_TCH.grib2.bz2                     |
# | icon-eu | icon-eu/grib/21/tcm/                 | grib      |       1 | REGULAR-LAT-LON_SINGLE-LEVEL_TCM           | icon-eu_europe_regular-lat-lon_single-level_{ref_time}_{lead}_TCM.grib2.bz2                     |
# | icon-eu | icon-eu/grib/21/td_2m/               | grib      |       1 | SINGLE-LEVEL_TD_2M                         | icon-eu_europe_regular-lat-lon_single-level_{ref_time}_{lead}_TD_2M.grib2.bz2                   |
# | icon-eu | icon-eu/grib/21/tke/                 | grib      |       1 | REGULAR-LAT-LON_MODEL-LEVEL_TKE            | icon-eu_europe_regular-lat-lon_model-level_{ref_time}_{lead}_{lead}_TKE.grib2.bz2               |
# | icon-eu | icon-eu/grib/21/tmax_2m/             | grib      |       1 | SINGLE-LEVEL_TMAX_2M                       | icon-eu_europe_regular-lat-lon_single-level_{ref_time}_{lead}_TMAX_2M.grib2.bz2                 |
# | icon-eu | icon-eu/grib/21/tmin_2m/             | grib      |       1 | SINGLE-LEVEL_TMIN_2M                       | icon-eu_europe_regular-lat-lon_single-level_{ref_time}_{lead}_TMIN_2M.grib2.bz2                 |
# | icon-eu | icon-eu/grib/21/tot_prec/            | grib      |       1 | SINGLE-LEVEL_TOT_PREC                      | icon-eu_europe_regular-lat-lon_single-level_{ref_time}_{lead}_TOT_PREC.grib2.bz2                |
# | icon-eu | icon-eu/grib/21/tqc/                 | grib      |       1 | REGULAR-LAT-LON_SINGLE-LEVEL_TQC           | icon-eu_europe_regular-lat-lon_single-level_{ref_time}_{lead}_TQC.grib2.bz2                     |
# | icon-eu | icon-eu/grib/21/tqi/                 | grib      |       1 | REGULAR-LAT-LON_SINGLE-LEVEL_TQI           | icon-eu_europe_regular-lat-lon_single-level_{ref_time}_{lead}_TQI.grib2.bz2                     |
# | icon-eu | icon-eu/grib/21/tqr/                 | grib      |       1 | REGULAR-LAT-LON_SINGLE-LEVEL_TQR           | icon-eu_europe_regular-lat-lon_single-level_{ref_time}_{lead}_TQR.grib2.bz2                     |
# | icon-eu | icon-eu/grib/21/tqs/                 | grib      |       1 | REGULAR-LAT-LON_SINGLE-LEVEL_TQS           | icon-eu_europe_regular-lat-lon_single-level_{ref_time}_{lead}_TQS.grib2.bz2                     |
# | icon-eu | icon-eu/grib/21/tqv/                 | grib      |       1 | REGULAR-LAT-LON_SINGLE-LEVEL_TQV           | icon-eu_europe_regular-lat-lon_single-level_{ref_time}_{lead}_TQV.grib2.bz2                     |
# | icon-eu | icon-eu/grib/21/u/                   | grib      |       1 | REGULAR-LAT-LON_MODEL-LEVEL_U              | icon-eu_europe_regular-lat-lon_model-level_{ref_time}_{lead}_{lead}_U.grib2.bz2                 |
# | icon-eu | icon-eu/grib/21/u_10m/               | grib      |       1 | SINGLE-LEVEL_U_10M                         | icon-eu_europe_regular-lat-lon_single-level_{ref_time}_{lead}_U_{lead}M.grib2.bz2               |
# | icon-eu | icon-eu/grib/21/v/                   | grib      |       1 | REGULAR-LAT-LON_MODEL-LEVEL_V              | icon-eu_europe_regular-lat-lon_model-level_{ref_time}_{lead}_{lead}_V.grib2.bz2                 |
# | icon-eu | icon-eu/grib/21/v_10m/               | grib      |       1 | SINGLE-LEVEL_V_10M                         | icon-eu_europe_regular-lat-lon_single-level_{ref_time}_{lead}_V_{lead}M.grib2.bz2               |
# | icon-eu | icon-eu/grib/21/vis/                 | grib      |       1 | REGULAR-LAT-LON_SINGLE-LEVEL_VIS           | icon-eu_europe_regular-lat-lon_single-level_{ref_time}_{lead}_VIS.grib2.bz2                     |
# | icon-eu | icon-eu/grib/21/vmax_10m/            | grib      |       1 | SINGLE-LEVEL_VMAX_10M                      | icon-eu_europe_regular-lat-lon_single-level_{ref_time}_{lead}_VMAX_{lead}M.grib2.bz2            |
# | icon-eu | icon-eu/grib/21/w/                   | grib      |       1 | REGULAR-LAT-LON_MODEL-LEVEL_W              | icon-eu_europe_regular-lat-lon_model-level_{ref_time}_{lead}_{lead}_W.grib2.bz2                 |
# | icon-eu | icon-eu/grib/21/w_snow/              | grib      |       1 | SINGLE-LEVEL_W_SNOW                        | icon-eu_europe_regular-lat-lon_single-level_{ref_time}_{lead}_W_SNOW.grib2.bz2                  |
# | icon-eu | icon-eu/grib/21/w_so/                | grib      |       2 | SOIL-LEVEL_W_SO, W_SO                      | icon-eu_europe_regular-lat-lon_soil-level_{ref_time}_{lead}_0_W_SO.grib2.bz2                    |
# | icon-eu | icon-eu/grib/21/w_so_ice/            | grib      |       1 | W_SO_ICE                                   | icon-eu_europe_regular-lat-lon_soil-level_{ref_time}_{lead}_0_W_SO_ICE.grib2.bz2                |
# | icon-eu | icon-eu/grib/21/ww/                  | grib      |       1 | REGULAR-LAT-LON_SINGLE-LEVEL_WW            | icon-eu_europe_regular-lat-lon_single-level_{ref_time}_{lead}_WW.grib2.bz2                      |
# | icon-eu | icon-eu/grib/21/z0/                  | grib      |       1 | REGULAR-LAT-LON_SINGLE-LEVEL_Z0            | icon-eu_europe_regular-lat-lon_single-level_{ref_time}_{lead}_Z0.grib2.bz2                      |

# %%
# ============================================================
# Condensation helpers for DWD NWP inventory
# ============================================================

import re
from collections import defaultdict


def canonical_variable(var: str) -> str:
    """
    Strip structural prefixes to get canonical variable names.
    """
    v = var.upper()
    for prefix in (
        "ICOSAHEDRAL_",
        "SINGLE-LEVEL_",
        "MODEL-LEVEL_",
        "PRESSURE-LEVEL_",
        "SOIL-LEVEL_",
        "TIME-INVARIANT_",
    ):
        if v.startswith(prefix):
            v = v[len(prefix):]
    return v


def infer_level(var: str) -> str:
    v = var.upper()
    if "MODEL-LEVEL" in v:
        return "model-level"
    if "PRESSURE-LEVEL" in v:
        return "pressure-level"
    if "SOIL-LEVEL" in v:
        return "soil-level"
    if "TIME-INVARIANT" in v:
        return "time-invariant"
    return "single-level"


def infer_grid(template: str) -> str:
    t = template.lower()
    if "regular-lat-lon" in t:
        return "regular-lat-lon"
    if "icosahedral" in t:
        return "icosahedral"
    return "unknown"


def infer_domain(model: str, template: str) -> str:
    t = template.lower()
    if "germany" in t or model == "icon-d2":
        return "germany"
    if "europe" in t or model == "icon-eu":
        return "europe"
    return "global"


def infer_ref_time_pattern(template: str) -> str:
    """
    Reference (cycle) time is encoded in the filename as YYYYMMDDHH.
    """
    return "YYYYMMDDHH" if "{ref_time}" in template else "unknown"


def infer_lead_time_pattern(template: str) -> str:
    """
    Forecast lead time is encoded in the filename as forecast hour.
    """
    return "forecast_hour" if "{lead}" in template else "unknown"


def condense_inventory(inventory: dict) -> list[dict]:
    """
    Condense product-level inventory into one row per (model, variable)
    with semantic availability metadata.
    """
    rows = []

    for model, mdata in inventory["models"].items():
        acc = defaultdict(lambda: {
            "model": model,
            "variable": None,
            "levels": set(),
            "domains": set(),
            "grids": set(),
            "formats": set(),
            "ref_time_pattern": set(),
            "lead_time_pattern": set(),
        })

        for p in mdata["products"]:
            for var in p["variables"]:
                cvar = canonical_variable(var)
                entry = acc[cvar]

                entry["variable"] = cvar
                entry["levels"].add(infer_level(var))
                entry["formats"].update(p["formats"])

                for templ in p["templates"]:
                    entry["grids"].add(infer_grid(templ))
                    entry["domains"].add(infer_domain(model, templ))
                    entry["ref_time_pattern"].add(
                        infer_ref_time_pattern(templ)
                    )
                    entry["lead_time_pattern"].add(
                        infer_lead_time_pattern(templ)
                    )

        for v in acc.values():
            rows.append({
                "model": v["model"],
                "variable": v["variable"],
                "levels": ", ".join(sorted(v["levels"])),
                "domain": ", ".join(sorted(v["domains"])),
                "grid": ", ".join(sorted(v["grids"])),
                "formats": ", ".join(sorted(v["formats"])),
                "reference_time": ", ".join(sorted(v["ref_time_pattern"])),
                "forecast_lead_time": ", ".join(sorted(v["lead_time_pattern"])),
            })

    return rows

# %%
# ============================================================
# Execute condensation and display result
# ============================================================

import json
import pandas as pd

# ---------- load inventory ----------
with open("dwd_nwp_inventory.json", "r", encoding="utf-8") as f:
    inventory = json.load(f)

# ---------- condense ----------
rows = condense_inventory(inventory)

df_condensed = (
    pd.DataFrame(rows)
    .sort_values(["model", "variable"])
    .reset_index(drop=True)
)

print("\n--- Condensed variable availability (Markdown) ---\n")
print(df_condensed.to_markdown(index=False))
# Out:
# --- Condensed variable availability (Markdown) ---
#
# | model   | variable                               | levels                   | domain   | grid                         | formats   | reference_time   | forecast_lead_time   |
# |:--------|:---------------------------------------|:-------------------------|:---------|:-----------------------------|:----------|:-----------------|:---------------------|
# | icon    | ALB_RAD                                | single-level             | global   | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon    | ALB_SEAICE                             | time-invariant           | global   | icosahedral                  | grib      | YYYYMMDDHH       | unknown              |
# | icon    | ALHFL_S                                | single-level             | global   | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon    | ASHFL_S                                | single-level             | global   | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon    | ASOB_S                                 | single-level             | global   | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon    | ASOB_S_CS                              | single-level             | global   | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon    | ASOB_T                                 | single-level             | global   | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon    | ASWDIFD_S                              | single-level             | global   | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon    | ASWDIFU_S                              | single-level             | global   | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon    | ASWDIR_S                               | single-level             | global   | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon    | ATHB_S                                 | single-level             | global   | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon    | ATHB_T                                 | single-level             | global   | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon    | AUMFL_S                                | single-level             | global   | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon    | AVMFL_S                                | single-level             | global   | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon    | CAPE_CON                               | single-level             | global   | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon    | CAPE_ML                                | single-level             | global   | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon    | CLAT                                   | time-invariant           | global   | icosahedral                  | grib      | YYYYMMDDHH       | unknown              |
# | icon    | CLC                                    | model-level              | global   | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon    | CLCH                                   | single-level             | global   | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon    | CLCL                                   | single-level             | global   | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon    | CLCM                                   | single-level             | global   | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon    | CLCT                                   | single-level             | global   | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon    | CLCT_MOD                               | single-level             | global   | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon    | CLDEPTH                                | single-level             | global   | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon    | CLON                                   | time-invariant           | global   | icosahedral                  | grib      | YYYYMMDDHH       | unknown              |
# | icon    | C_T_LK                                 | single-level             | global   | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon    | DEPTH_LK                               | time-invariant           | global   | icosahedral                  | grib      | YYYYMMDDHH       | unknown              |
# | icon    | ELAT                                   | time-invariant           | global   | icosahedral                  | grib      | YYYYMMDDHH       | unknown              |
# | icon    | ELON                                   | time-invariant           | global   | icosahedral                  | grib      | YYYYMMDDHH       | unknown              |
# | icon    | EVAP_PL                                | time-invariant           | global   | icosahedral                  | grib      | YYYYMMDDHH       | unknown              |
# | icon    | FI                                     | pressure-level           | global   | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon    | FRESHSNW                               | single-level             | global   | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon    | FR_ICE                                 | single-level             | global   | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon    | FR_LAKE                                | time-invariant           | global   | icosahedral                  | grib      | YYYYMMDDHH       | unknown              |
# | icon    | FR_LAND                                | time-invariant           | global   | icosahedral                  | grib      | YYYYMMDDHH       | unknown              |
# | icon    | HBAS_CON                               | single-level             | global   | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon    | HHL                                    | time-invariant           | global   | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon    | HSNOW_MAX                              | time-invariant           | global   | icosahedral                  | grib      | YYYYMMDDHH       | unknown              |
# | icon    | HSURF                                  | time-invariant           | global   | icosahedral                  | grib      | YYYYMMDDHH       | unknown              |
# | icon    | HTOP_CON                               | single-level             | global   | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon    | HTOP_DC                                | single-level             | global   | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon    | HZEROCL                                | single-level             | global   | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon    | H_ICE                                  | single-level             | global   | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon    | H_ML_LK                                | single-level             | global   | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon    | H_SNOW                                 | single-level             | global   | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon    | LAI                                    | time-invariant           | global   | icosahedral                  | grib      | YYYYMMDDHH       | unknown              |
# | icon    | NDVIRATIO                              | time-invariant           | global   | icosahedral                  | grib      | YYYYMMDDHH       | unknown              |
# | icon    | P                                      | model-level              | global   | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon    | PLCOV                                  | time-invariant           | global   | icosahedral                  | grib      | YYYYMMDDHH       | unknown              |
# | icon    | PMSL                                   | single-level             | global   | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon    | PS                                     | single-level             | global   | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon    | QC                                     | model-level              | global   | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon    | QI                                     | model-level              | global   | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon    | QV                                     | model-level              | global   | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon    | QV_S                                   | single-level             | global   | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon    | RAIN_CON                               | single-level             | global   | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon    | RAIN_GSP                               | single-level             | global   | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon    | RELHUM                                 | pressure-level           | global   | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon    | RELHUM_2M                              | single-level             | global   | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon    | RHO_SNOW                               | single-level             | global   | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon    | ROOTDP                                 | time-invariant           | global   | icosahedral                  | grib      | YYYYMMDDHH       | unknown              |
# | icon    | RUNOFF_G                               | single-level             | global   | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon    | RUNOFF_S                               | single-level             | global   | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon    | SNOAG                                  | time-invariant           | global   | icosahedral                  | grib      | YYYYMMDDHH       | unknown              |
# | icon    | SNOW_CON                               | single-level             | global   | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon    | SNOW_GSP                               | single-level             | global   | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon    | SOILTYP                                | time-invariant           | global   | icosahedral                  | grib      | YYYYMMDDHH       | unknown              |
# | icon    | T                                      | model-level              | global   | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon    | TCH                                    | single-level             | global   | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon    | TCM                                    | single-level             | global   | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon    | TD_2M                                  | single-level             | global   | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon    | TKE                                    | model-level              | global   | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon    | TMAX_2M                                | single-level             | global   | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon    | TMIN_2M                                | single-level             | global   | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon    | TOT_PREC                               | single-level             | global   | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon    | TQC                                    | single-level             | global   | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon    | TQC_DIA                                | single-level             | global   | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon    | TQI                                    | single-level             | global   | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon    | TQI_DIA                                | single-level             | global   | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon    | TQR                                    | single-level             | global   | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon    | TQS                                    | single-level             | global   | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon    | TQV                                    | single-level             | global   | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon    | T_2M                                   | single-level             | global   | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon    | T_BOT_LK                               | single-level             | global   | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon    | T_G                                    | single-level             | global   | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon    | T_ICE                                  | single-level             | global   | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon    | T_MNW_LK                               | single-level             | global   | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon    | T_SNOW                                 | single-level             | global   | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon    | T_SO                                   | single-level, soil-level | global   | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon    | T_WML_LK                               | single-level             | global   | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon    | U                                      | model-level              | global   | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon    | U_10M                                  | single-level             | global   | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon    | V                                      | model-level              | global   | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon    | VMAX_10M                               | single-level             | global   | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon    | V_10M                                  | single-level             | global   | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon    | W                                      | model-level              | global   | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon    | WW                                     | single-level             | global   | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon    | W_I                                    | single-level             | global   | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon    | W_SNOW                                 | single-level             | global   | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon    | W_SO                                   | single-level, soil-level | global   | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon    | W_SO_ICE                               | single-level             | global   | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon    | Z0                                     | single-level             | global   | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | 2D_ALB_RAD                             | single-level             | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | 2D_ALHFL_S                             | single-level             | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | 2D_APAB_S                              | single-level             | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | 2D_ASHFL_S                             | single-level             | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | 2D_ASOB_S                              | single-level             | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | 2D_ASOB_T                              | single-level             | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | 2D_ASWDIFD_S                           | single-level             | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | 2D_ASWDIFU_S                           | single-level             | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | 2D_ASWDIR_S                            | single-level             | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | 2D_ATHB_S                              | single-level             | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | 2D_ATHB_T                              | single-level             | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | 2D_AUMFL_S                             | single-level             | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | 2D_AVMFL_S                             | single-level             | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | 2D_CAPE_ML                             | single-level             | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | 2D_CEILING                             | single-level             | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | 2D_CIN_ML                              | single-level             | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | 2D_CLCH                                | single-level             | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | 2D_CLCL                                | single-level             | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | 2D_CLCM                                | single-level             | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | 2D_CLCT                                | single-level             | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | 2D_CLCT_MOD                            | single-level             | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | 2D_CLDEPTH                             | single-level             | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | 2D_DBZ                                 | single-level             | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | 2D_DBZ_CMAX                            | single-level             | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | 2D_DBZ_CTMAX                           | single-level             | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | 2D_ECHOTOP                             | single-level             | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | 2D_FRESHSNW                            | single-level             | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | 2D_GRAU_GSP                            | single-level             | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | 2D_HBAS_SC                             | single-level             | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | 2D_HTOP_DC                             | single-level             | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | 2D_HTOP_SC                             | single-level             | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | 2D_HZEROCL                             | single-level             | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | 2D_H_ICE                               | single-level             | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | 2D_H_SNOW                              | single-level             | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | 2D_LPI                                 | single-level             | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | 2D_LPI_MAX                             | single-level             | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | 2D_MH                                  | single-level             | germany  | regular-lat-lon              | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | 2D_PMSL                                | single-level             | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | 2D_PRG_GSP                             | single-level             | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | 2D_PRR_GSP                             | single-level             | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | 2D_PRS_GSP                             | single-level             | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | 2D_PS                                  | single-level             | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | 2D_QV_S                                | single-level             | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | 2D_RAIN_CON                            | single-level             | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | 2D_RAIN_GSP                            | single-level             | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | 2D_RELHUM_2M                           | single-level             | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | 2D_RHO_SNOW                            | single-level             | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | 2D_RUNOFF_G                            | single-level             | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | 2D_RUNOFF_S                            | single-level             | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | 2D_SDI                                 | single-level             | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | 2D_SNOWC                               | single-level             | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | 2D_SNOWLMT                             | single-level             | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | 2D_SNOW_CON                            | single-level             | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | 2D_SNOW_GSP                            | single-level             | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | 2D_TCH                                 | single-level             | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | 2D_TCM                                 | single-level             | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | 2D_TCOND10_MX                          | single-level             | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | 2D_TCOND_MAX                           | single-level             | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | 2D_TD_2M                               | single-level             | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | 2D_TMAX_2M                             | single-level             | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | 2D_TMIN_2M                             | single-level             | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | 2D_TOT_PREC                            | single-level             | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | 2D_TQC                                 | single-level             | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | 2D_TQC_DIA                             | single-level             | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | 2D_TQG                                 | single-level             | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | 2D_TQI                                 | single-level             | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | 2D_TQI_DIA                             | single-level             | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | 2D_TQR                                 | single-level             | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | 2D_TQS                                 | single-level             | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | 2D_TQV                                 | single-level             | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | 2D_TQV_DIA                             | single-level             | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | 2D_TWATER                              | single-level             | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | 2D_T_2M                                | single-level             | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | 2D_T_G                                 | single-level             | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | 2D_T_ICE                               | single-level             | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | 2D_T_SNOW                              | single-level             | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | 2D_UH_MAX                              | single-level             | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | 2D_U_10M                               | single-level             | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | 2D_VIS                                 | single-level             | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | 2D_VMAX_10M                            | single-level             | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | 2D_VORW_CTMAX                          | single-level             | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | 2D_V_10M                               | single-level             | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | 2D_WW                                  | single-level             | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | 2D_W_CTMAX                             | single-level             | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | 2D_W_I                                 | single-level             | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | 2D_W_SNOW                              | single-level             | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | 2D_Z0                                  | single-level             | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | BT_CL_IR10.8                           | single-level             | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | BT_CL_WV6.2                            | single-level             | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | CLAT                                   | time-invariant           | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | CLC                                    | model-level              | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | CLON                                   | time-invariant           | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | C_T_LK                                 | single-level             | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | DEPTH_LK                               | single-level             | germany  | icosahedral, regular-lat-lon | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | ELAT                                   | time-invariant           | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | ELON                                   | time-invariant           | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | FI                                     | pressure-level           | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | FR_ICE                                 | single-level             | germany  | icosahedral, regular-lat-lon | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | FR_LAKE                                | single-level             | germany  | icosahedral, regular-lat-lon | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | FR_LAND                                | single-level             | germany  | icosahedral, regular-lat-lon | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | HHL                                    | time-invariant           | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | HSURF                                  | time-invariant           | germany  | icosahedral, regular-lat-lon | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | H_ML_LK                                | single-level             | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | LAI                                    | time-invariant           | germany  | icosahedral, regular-lat-lon | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | OMEGA                                  | pressure-level           | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | P                                      | model-level              | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | PLCOV                                  | time-invariant           | germany  | icosahedral, regular-lat-lon | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | QC                                     | model-level              | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | QG                                     | model-level              | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | QI                                     | model-level              | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | QR                                     | model-level              | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | QS                                     | model-level              | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | QV                                     | model-level              | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | Q_SEDIM                                | model-level              | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | RELHUM                                 | pressure-level           | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | ROOTDP                                 | time-invariant           | germany  | icosahedral, regular-lat-lon | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | SMI                                    | soil-level               | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | SOILTYP                                | time-invariant           | germany  | icosahedral, regular-lat-lon | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | T                                      | model-level              | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | TKE                                    | model-level              | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | T_BOT_LK                               | single-level             | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | T_MNW_LK                               | single-level             | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | T_SO                                   | single-level, soil-level | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | T_WML_LK                               | single-level             | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | U                                      | model-level              | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | UH_MAX_LOW                             | single-level             | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | UH_MAX_MED                             | single-level             | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | V                                      | model-level              | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | W                                      | model-level              | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | W_SO                                   | single-level, soil-level | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-d2 | W_SO_ICE                               | single-level             | germany  | icosahedral                  | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-eu | ALB_RAD                                | single-level             | europe   | regular-lat-lon              | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-eu | ALHFL_S                                | single-level             | europe   | regular-lat-lon              | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-eu | APAB_S                                 | single-level             | europe   | regular-lat-lon              | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-eu | ASHFL_S                                | single-level             | europe   | regular-lat-lon              | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-eu | ASOB_S                                 | single-level             | europe   | regular-lat-lon              | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-eu | ASOB_S_CS                              | single-level             | europe   | regular-lat-lon              | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-eu | ASOB_T                                 | single-level             | europe   | regular-lat-lon              | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-eu | ASWDIFD_S                              | single-level             | europe   | regular-lat-lon              | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-eu | ASWDIFU_S                              | single-level             | europe   | regular-lat-lon              | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-eu | ASWDIR_S                               | single-level             | europe   | regular-lat-lon              | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-eu | ATHB_S                                 | single-level             | europe   | regular-lat-lon              | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-eu | ATHB_T                                 | single-level             | europe   | regular-lat-lon              | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-eu | AUMFL_S                                | single-level             | europe   | regular-lat-lon              | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-eu | AVMFL_S                                | single-level             | europe   | regular-lat-lon              | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-eu | BT_CL_IR10.8                           | single-level             | europe   | regular-lat-lon              | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-eu | BT_CL_WV6.2                            | single-level             | europe   | regular-lat-lon              | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-eu | CAPE_CON                               | single-level             | europe   | regular-lat-lon              | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-eu | CAPE_ML                                | single-level             | europe   | regular-lat-lon              | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-eu | CIN_ML                                 | single-level             | europe   | regular-lat-lon              | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-eu | CLCT_MOD                               | single-level             | europe   | regular-lat-lon              | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-eu | DEPTH_LK                               | time-invariant           | europe   | regular-lat-lon              | grib      | YYYYMMDDHH       | unknown              |
# | icon-eu | FR_LAKE                                | time-invariant           | europe   | regular-lat-lon              | grib      | YYYYMMDDHH       | unknown              |
# | icon-eu | FR_LAND                                | time-invariant           | europe   | regular-lat-lon              | grib      | YYYYMMDDHH       | unknown              |
# | icon-eu | HBAS_CON                               | single-level             | europe   | regular-lat-lon              | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-eu | HTOP_CON                               | single-level             | europe   | regular-lat-lon              | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-eu | HTOP_DC                                | single-level             | europe   | regular-lat-lon              | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-eu | H_ICE                                  | single-level             | europe   | regular-lat-lon              | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-eu | H_SNOW                                 | single-level             | europe   | regular-lat-lon              | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-eu | LPI_CON_MAX                            | single-level             | europe   | regular-lat-lon              | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-eu | QV_2M                                  | single-level             | europe   | regular-lat-lon              | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-eu | QV_S                                   | single-level             | europe   | regular-lat-lon              | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-eu | RAIN_CON                               | single-level             | europe   | regular-lat-lon              | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-eu | RAIN_GSP                               | single-level             | europe   | regular-lat-lon              | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-eu | REGULAR-LAT-LON_MODEL-LEVEL_CLC        | model-level              | europe   | regular-lat-lon              | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-eu | REGULAR-LAT-LON_MODEL-LEVEL_P          | model-level              | europe   | regular-lat-lon              | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-eu | REGULAR-LAT-LON_MODEL-LEVEL_QC         | model-level              | europe   | regular-lat-lon              | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-eu | REGULAR-LAT-LON_MODEL-LEVEL_QI         | model-level              | europe   | regular-lat-lon              | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-eu | REGULAR-LAT-LON_MODEL-LEVEL_QV         | model-level              | europe   | regular-lat-lon              | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-eu | REGULAR-LAT-LON_MODEL-LEVEL_T          | model-level              | europe   | regular-lat-lon              | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-eu | REGULAR-LAT-LON_MODEL-LEVEL_TKE        | model-level              | europe   | regular-lat-lon              | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-eu | REGULAR-LAT-LON_MODEL-LEVEL_U          | model-level              | europe   | regular-lat-lon              | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-eu | REGULAR-LAT-LON_MODEL-LEVEL_V          | model-level              | europe   | regular-lat-lon              | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-eu | REGULAR-LAT-LON_MODEL-LEVEL_W          | model-level              | europe   | regular-lat-lon              | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-eu | REGULAR-LAT-LON_PRESSURE-LEVEL_FI      | pressure-level           | europe   | regular-lat-lon              | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-eu | REGULAR-LAT-LON_PRESSURE-LEVEL_OMEGA   | pressure-level           | europe   | regular-lat-lon              | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-eu | REGULAR-LAT-LON_PRESSURE-LEVEL_RELHUM  | pressure-level           | europe   | regular-lat-lon              | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-eu | REGULAR-LAT-LON_SINGLE-LEVEL_CEILING   | single-level             | europe   | regular-lat-lon              | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-eu | REGULAR-LAT-LON_SINGLE-LEVEL_CLCH      | single-level             | europe   | regular-lat-lon              | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-eu | REGULAR-LAT-LON_SINGLE-LEVEL_CLCL      | single-level             | europe   | regular-lat-lon              | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-eu | REGULAR-LAT-LON_SINGLE-LEVEL_CLCM      | single-level             | europe   | regular-lat-lon              | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-eu | REGULAR-LAT-LON_SINGLE-LEVEL_CLCT      | single-level             | europe   | regular-lat-lon              | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-eu | REGULAR-LAT-LON_SINGLE-LEVEL_CLDEPTH   | single-level             | europe   | regular-lat-lon              | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-eu | REGULAR-LAT-LON_SINGLE-LEVEL_HZEROCL   | single-level             | europe   | regular-lat-lon              | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-eu | REGULAR-LAT-LON_SINGLE-LEVEL_MH        | single-level             | europe   | regular-lat-lon              | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-eu | REGULAR-LAT-LON_SINGLE-LEVEL_PMSL      | single-level             | europe   | regular-lat-lon              | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-eu | REGULAR-LAT-LON_SINGLE-LEVEL_PS        | single-level             | europe   | regular-lat-lon              | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-eu | REGULAR-LAT-LON_SINGLE-LEVEL_SNOWLMT   | single-level             | europe   | regular-lat-lon              | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-eu | REGULAR-LAT-LON_SINGLE-LEVEL_TCH       | single-level             | europe   | regular-lat-lon              | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-eu | REGULAR-LAT-LON_SINGLE-LEVEL_TCM       | single-level             | europe   | regular-lat-lon              | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-eu | REGULAR-LAT-LON_SINGLE-LEVEL_TQC       | single-level             | europe   | regular-lat-lon              | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-eu | REGULAR-LAT-LON_SINGLE-LEVEL_TQI       | single-level             | europe   | regular-lat-lon              | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-eu | REGULAR-LAT-LON_SINGLE-LEVEL_TQR       | single-level             | europe   | regular-lat-lon              | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-eu | REGULAR-LAT-LON_SINGLE-LEVEL_TQS       | single-level             | europe   | regular-lat-lon              | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-eu | REGULAR-LAT-LON_SINGLE-LEVEL_TQV       | single-level             | europe   | regular-lat-lon              | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-eu | REGULAR-LAT-LON_SINGLE-LEVEL_VIS       | single-level             | europe   | regular-lat-lon              | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-eu | REGULAR-LAT-LON_SINGLE-LEVEL_WW        | single-level             | europe   | regular-lat-lon              | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-eu | REGULAR-LAT-LON_SINGLE-LEVEL_Z0        | single-level             | europe   | regular-lat-lon              | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-eu | REGULAR-LAT-LON_TIME-INVARIANT_HHL     | time-invariant           | europe   | regular-lat-lon              | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-eu | REGULAR-LAT-LON_TIME-INVARIANT_HSURF   | time-invariant           | europe   | regular-lat-lon              | grib      | YYYYMMDDHH       | unknown              |
# | icon-eu | REGULAR-LAT-LON_TIME-INVARIANT_LAI     | time-invariant           | europe   | regular-lat-lon              | grib      | YYYYMMDDHH       | unknown              |
# | icon-eu | REGULAR-LAT-LON_TIME-INVARIANT_PLCOV   | time-invariant           | europe   | regular-lat-lon              | grib      | YYYYMMDDHH       | unknown              |
# | icon-eu | REGULAR-LAT-LON_TIME-INVARIANT_RLAT    | time-invariant           | europe   | regular-lat-lon              | grib      | YYYYMMDDHH       | unknown              |
# | icon-eu | REGULAR-LAT-LON_TIME-INVARIANT_RLON    | time-invariant           | europe   | regular-lat-lon              | grib      | YYYYMMDDHH       | unknown              |
# | icon-eu | REGULAR-LAT-LON_TIME-INVARIANT_ROOTDP  | time-invariant           | europe   | regular-lat-lon              | grib      | YYYYMMDDHH       | unknown              |
# | icon-eu | REGULAR-LAT-LON_TIME-INVARIANT_SOILTYP | time-invariant           | europe   | regular-lat-lon              | grib      | YYYYMMDDHH       | unknown              |
# | icon-eu | RELHUM_2M                              | single-level             | europe   | regular-lat-lon              | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-eu | RHO_SNOW                               | single-level             | europe   | regular-lat-lon              | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-eu | RUNOFF_G                               | single-level             | europe   | regular-lat-lon              | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-eu | RUNOFF_S                               | single-level             | europe   | regular-lat-lon              | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-eu | SNOW_CON                               | single-level             | europe   | regular-lat-lon              | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-eu | SNOW_GSP                               | single-level             | europe   | regular-lat-lon              | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-eu | TD_2M                                  | single-level             | europe   | regular-lat-lon              | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-eu | TMAX_2M                                | single-level             | europe   | regular-lat-lon              | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-eu | TMIN_2M                                | single-level             | europe   | regular-lat-lon              | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-eu | TOT_PREC                               | single-level             | europe   | regular-lat-lon              | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-eu | T_2M                                   | single-level             | europe   | regular-lat-lon              | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-eu | T_G                                    | single-level             | europe   | regular-lat-lon              | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-eu | T_ICE                                  | single-level             | europe   | regular-lat-lon              | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-eu | T_SNOW                                 | single-level             | europe   | regular-lat-lon              | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-eu | T_SO                                   | single-level, soil-level | europe   | regular-lat-lon              | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-eu | U_10M                                  | single-level             | europe   | regular-lat-lon              | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-eu | VMAX_10M                               | single-level             | europe   | regular-lat-lon              | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-eu | V_10M                                  | single-level             | europe   | regular-lat-lon              | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-eu | W_SNOW                                 | single-level             | europe   | regular-lat-lon              | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-eu | W_SO                                   | single-level, soil-level | europe   | regular-lat-lon              | grib      | YYYYMMDDHH       | forecast_hour        |
# | icon-eu | W_SO_ICE                               | single-level             | europe   | regular-lat-lon              | grib      | YYYYMMDDHH       | forecast_hour        |
